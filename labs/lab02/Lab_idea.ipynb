# %% [markdown]
# ### Laboratoria 2

# %% [markdown]
# Podczas tych zajęć przypomnimy sobie jak poprawnie trenować i testować pipeline ML.

# %% [markdown]
# #### Zadanie 1
# Czym jest zjawisko overfittingu?

# %% [markdown]
# #### Zadanie 2
# Porównaj wyniki uzyskane ze zwykłej kroswalidacji i z zagnieżdżonej kroswalidacji?
#
# *Pomysł: możemy wykorzystać przykład z tego kursu AutoML- można to opowiedzieć na wykładzie, ale potem dać zadanie na labach*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Zadanie 3
#
# Wymyślić jakieś zadanie z tym związane https://machinelearningmastery.com/data-preparation-without-data-leakage/
#
# Pomysł: wykorzystać przykłady symulacyjne z tego artykułu [On the cross-validation bias due to unsupervised preprocessing](https://academic.oup.com/jrsssb/article/84/4/1474/7073256)

# %% [markdown]
# #### Zadanie 4
#
# Zaimplementuj cały pipeline ML z wykorzystaniem `sklearn.compose.ColumnTransformer` i `sklearn.pipeline.Pipeline`

# %% [markdown]
# #### Zadanie 5
# Zaimplementuj stacking używając bazowego Pythona

# %% [markdown]
# #### Zadanie 6
# Zaimplementuj stacking używając `sklearn.ensemble.StackingClassifier` lub `sklearn.ensemble.StackingRegressor`

# %% [markdown]
# #### Zadanie 7
# Symulacje Bagged selection z artykułu
#
# ![image.png](attachment:image.png)
