# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Wykresy dla KNN

# %%
knn_score_kddc = np.load('knn_score_kddc.npy',allow_pickle=True).item()
knn_score_santa_nder = np.load('knn_score_santa_nder.npy',allow_pickle=True).item()
knn_score_click = np.load('knn_score_click.npy',allow_pickle=True).item()
knn_score_christine = np.load('knn_score_christine.npy',allow_pickle=True).item()

# %%
mean_test_score_knn_kddc = knn_score_kddc['mean_test_score']
mean_test_score_knn_santa_nder = knn_score_santa_nder['mean_test_score']
mean_test_score_knn_click = knn_score_click['mean_test_score']
mean_test_score_knn_christine = knn_score_christine['mean_test_score']

# %%
knn_score = pd.DataFrame([mean_test_score_knn_click,mean_test_score_knn_santa_nder,mean_test_score_knn_christine,mean_test_score_knn_kddc])

# %%
mean_knn = knn_score.mean()
which = np.where(mean_knn.max()==knn_score.mean())

# %%
params =np.array( [{'weights': 'uniform', 'p': 1, 'n_neighbors': 12}, {'weights': 'distance', 'p': 2, 'n_neighbors': 12}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 2}, {'weights': 'distance', 'p': 2, 'n_neighbors': 14}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 7}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 17}, {'weights': 'distance', 'p': 1, 'n_neighbors': 19}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 3}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 11}, {'weights': 'distance', 'p': 2, 'n_neighbors': 27}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 5}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 16}, {'weights': 'distance', 'p': 2, 'n_neighbors': 3}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 10}, {'weights': 'distance', 'p': 1, 'n_neighbors': 23}, {'weights': 'distance', 'p': 2, 'n_neighbors': 23}, {'weights': 'distance', 'p': 1, 'n_neighbors': 28}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 1}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 23}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 27}, {'weights': 'distance', 'p': 1, 'n_neighbors': 17}, {'weights': 'distance', 'p': 1, 'n_neighbors': 12}, {'weights': 'distance', 'p': 2, 'n_neighbors': 8}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 18}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 11}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 4}, {'weights': 'distance', 'p': 2, 'n_neighbors': 4}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 29}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 20}, {'weights': 'distance', 'p': 1, 'n_neighbors': 25}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 7}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 20}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 6}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 25}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 15}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 28}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 8}, {'weights': 'distance', 'p': 1, 'n_neighbors': 14}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 30}, {'weights': 'distance', 'p': 1, 'n_neighbors': 3}, {'weights': 'distance', 'p': 1, 'n_neighbors': 9}, {'weights': 'distance', 'p': 1, 'n_neighbors': 7}, {'weights': 'distance', 'p': 1, 'n_neighbors': 18}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 8}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 25}, {'weights': 'distance', 'p': 1, 'n_neighbors': 22}, {'weights': 'distance', 'p': 1, 'n_neighbors': 2}, {'weights': 'uniform', 'p': 2, 'n_neighbors': 23}, {'weights': 'uniform', 'p': 1, 'n_neighbors': 18}, {'weights': 'distance', 'p': 2, 'n_neighbors': 10}])

# %%
default = params[which]
def_score = mean_knn.max()

# %%
print(default)
print(def_score)
# Out:
# [{'weights': 'uniform', 'p': 1, 'n_neighbors': 25}]
# 0.7617701694003846

# %%
plt.boxplot([def_score-mean_knn])
plt.title('Tunowalność KNN dla Random Search')
plt.xlabel('KNN')
plt.ylabel('Różnica dokładności najlepszej kombinacji i reszty')
plt.xticks([])
plt.savefig('tunowalnosc_knn_rs.png')
plt.show()

# %%
difference_knn_random = knn_score-def_score

# %%
plt.boxplot(difference_knn_random.T,labels=['click','santander','christine','kddc'])
plt.title('Rozkład różnicy dokładności dla metody Random Search')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Różnica dokładności')
plt.savefig('bp_knn_df.png')
plt.show()

# %%
op_knn_score_christine = np.load('op_knn_score_christine.npy',allow_pickle=True).item()
op_knn_score_click = np.load('op_knn_score_click.npy',allow_pickle=True).item()
op_knn_score_santa_nder = np.load('op_knn_score_santa_nder.npy',allow_pickle=True).item()
op_knn_score_kddc = np.load('op_knn_score_kddc.npy',allow_pickle=True).item()

# %%
mean_op_knn_christine = op_knn_score_christine['mean_test_score']
mean_op_knn_click = op_knn_score_click['mean_test_score']
mean_op_knn_santa_nder = op_knn_score_santa_nder['mean_test_score']
mean_op_knn_kddc = op_knn_score_kddc['mean_test_score']

# %%
op_knn_score = pd.DataFrame([mean_op_knn_click,mean_op_knn_santa_nder,mean_op_knn_christine,mean_op_knn_kddc])

# %%
plt.boxplot(def_score-op_knn_score.mean())
plt.title('Tunowalność KNN dla metody bayesowskiej')
plt.xlabel('KNN')
plt.ylabel('Różnica dokładności najlepszej kombinacji i reszty')
plt.xticks([])
plt.savefig('tunowalnosc_knn_bayes.png')
plt.show()

# %%
difference_knn_bayes = op_knn_score-def_score

# %%
plt.boxplot(difference_knn_bayes.T,labels=['click','santander','christine','kddc'])
plt.title('Rozkład różnicy dokładności dla metody bayesowskiej')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Różnica dokładności')
plt.savefig('bp_kn_df_op.png')
plt.show()

# %%
plt.boxplot(op_knn_score.T,labels=['click','santander','christine','kddc'])
plt.title('Rozkład miary dopasowania dla metody bayesowskiej')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Wartość miary dopasowania')
plt.savefig('bp_knn_bayes.png')
plt.show()

# %%
plt.boxplot(knn_score.T,labels=['click','santander','christine','kddc'])
plt.title('Rozkład miary dopasowana dla metody Random Search')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Wartość miary dopasowania')
plt.savefig('bp_knn_score.png')
plt.show()

# %%
plt.plot(range(50), mean_op_knn_click)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru click')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_knn_click.png')
plt.show()

# %%
plt.plot(range(50), mean_op_knn_christine)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru christine')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_knn_christine.png')
plt.show()

# %%
plt.plot(range(50), mean_op_knn_kddc)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru kddc')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_knn_kddc.png')
plt.show()

# %%
plt.plot(range(50), mean_op_knn_santa_nder)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru santander')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_knn_santander.png')
plt.show()

# %% [markdown]
# ### Wykresy dla RandomForest

# %%
rf_score_kddc = np.load('randomforestclassifier_score_kddc.npy',allow_pickle=True).item()
rf_score_click = np.load('randomforestclassifier_score_click.npy',allow_pickle=True).item()
rf_score_santa_nder = np.load('randomforestclassifier_score_santa_nder.npy',allow_pickle=True).item()
rf_score_christine = np.load('randomforestclassifier_score_christine.npy',allow_pickle=True).item()

# %%
mean_rf_christine = rf_score_christine['mean_test_score']
mean_rf_click = rf_score_click['mean_test_score']
mean_rf_santa_nder = rf_score_santa_nder['mean_test_score']
mean_rf_kddc = rf_score_kddc['mean_test_score']

# %%
rf_score = pd.DataFrame([mean_rf_click,mean_rf_santa_nder,mean_rf_christine,mean_rf_kddc ])
print(rf_score)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.831581  0.831581  0.831581  0.831581  0.831581  0.831581  0.831581
# 1  0.898200  0.898200  0.898200  0.898200  0.898200  0.898200  0.898200
# 2  0.500000  0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 3  0.499801  0.499603  0.499801  0.499801  0.499801  0.499404  0.499801
#
#          7         8         9   ...        40        41        42        43  \
# 0  0.831581  0.831581  0.831581  ...  0.831581  0.831581  0.831581  0.831581
# 1  0.898200  0.898200  0.898200  ...  0.898200  0.898200  0.898200  0.898200
# 2  0.500000  0.500000  0.500000  ...  0.500000  0.500000  0.500000  0.500000
# 3  0.749811  0.500000  0.499801  ...  0.500596  0.796106  0.500199  0.499603
#
#          44        45        46        47        48        49
# 0  0.831581  0.831581  0.831581  0.831581  0.831581  0.831581
# 1  0.898200  0.898200  0.898200  0.898200  0.898200  0.898200
# ...

# %%
mean_rf = rf_score.mean()
which = np.where(mean_rf.max()==rf_score.mean())

# %%
params = np.array(rf_score_kddc['params'])

# %%
default = params[which]
def_score = mean_rf.max()

# %%
print(default)
print(def_score)
# Out:
# [{'n_estimators': 1263, 'min_samples_split': 53, 'min_samples_leaf': 50, 'max_samples': 0.8, 'max_depth': None, 'ccp_alpha': 0.0}]
# 0.8108708936435043

# %%
plt.boxplot([def_score-mean_rf])
plt.title('Tunowalność RandomForest dla metody Random Search')
plt.xlabel('RandomForest')
plt.ylabel('Różnica dokładności najlepszej kombinacji i reszty')
plt.xticks([])
plt.savefig('tunowalnosc_rf_rs.png')
plt.show()

# %%
difference_rf_random = rf_score-def_score

# %%
plt.boxplot(difference_rf_random.T,labels=['click','santander','christine','kddc'])
plt.title('Rozkład różnicy dokładności dla metody Random Search')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Różnica dokładności')
plt.savefig('bp_rf_df.png')
plt.show()

# %%
plt.boxplot(rf_score.T,labels=['click','santander','christine','kddc'])
plt.title('Rozkład miary dopasowania dla metody Random Search')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Wartość miary dopasowania')
plt.savefig('bp_rf_score.png')
plt.show()

# %%
op_rf_score_kddc = np.load('op_rf_score_kddc.npy',allow_pickle=True).item()
op_rf_score_click = np.load('op_rf_score_click.npy',allow_pickle=True).item()
op_rf_score_santa_nder = np.load('op_rf_score_santa_nder.npy',allow_pickle=True).item()
op_rf_score_christine = np.load('op_rf_score_christine.npy',allow_pickle=True).item()

# %%
mean_op_rf_christine = op_rf_score_christine['mean_test_score']
mean_op_rf_click = op_rf_score_click['mean_test_score']
mean_op_rf_santa_nder = op_rf_score_santa_nder['mean_test_score']
mean_op_rf_kddc = op_rf_score_kddc['mean_test_score']

# %%
op_rf_score = pd.DataFrame([mean_op_rf_click,mean_op_rf_santa_nder,mean_op_rf_christine,mean_op_rf_kddc ])

# %%
print(op_rf_score)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.831581  0.831581  0.831581  0.831581  0.831581  0.831581  0.831581
# 1  0.902200  0.902200  0.902200  0.902200  0.902200  0.902200  0.902200
# 2  0.500000  0.500000  0.500000  0.500000  0.500000  0.500000  0.500000
# 3  0.500000  0.500000  0.500000  0.499801  0.499801  0.500000  0.500000
#
#          7         8         9   ...        40        41        42        43  \
# 0  0.831581  0.831581  0.834785  ...  0.834034  0.833784  0.834360  0.816311
# 1  0.902200  0.902200  0.902200  ...       NaN       NaN       NaN       NaN
# 2  0.500000  0.500000  0.720377  ...       NaN       NaN       NaN       NaN
# 3  0.500199  0.499801  0.799284  ...  0.796106  0.795706  0.788154  0.792129
#
#          44        45        46        47        48        49
# 0  0.834285  0.834685  0.833183  0.831581  0.833208  0.833133
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
plt.boxplot([def_score-op_rf_score.mean()])
plt.title('Tunowalność RandomForest dla metody bayesowskiej')
plt.xlabel('RandomForest')
plt.ylabel('Różnica dokładności najlepszej kombinacji i reszty')
plt.xticks([])
plt.savefig('tunowalnosc_rf_bayes.png')
plt.show()

# %%
plt.boxplot([mean_op_rf_click-def_score,mean_op_rf_santa_nder-def_score,mean_op_rf_christine-def_score,mean_op_rf_kddc-def_score],labels=['click','santander','christine','kddc'])
plt.title('Rozkład różnicy dokładności dla metody bayesowskiej')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Różnica dokładności')
plt.savefig('bp_rf_df_op.png')
plt.show()

# %%
plt.boxplot([mean_op_rf_click,mean_op_rf_santa_nder,mean_op_rf_christine,mean_op_rf_kddc],labels=['click','santander','christine','kddc'])
plt.title('Rozkład miary dopasowania dla metody bayesowskiej')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Wartość miary dopasowania')
plt.savefig('bp_rf_bayes.png')
plt.show()

# %%
plt.plot(range(50), mean_op_rf_click)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru click')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_las_click.png')
plt.show()

# %%
plt.plot(range(30), mean_op_rf_santa_nder)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru santander')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_las_santa.png')
plt.show()

# %%
mean_op_rf_santa_nder
# Out:
# array([0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022,
#        0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022,
#        0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022,
#        0.9022, 0.9022, 0.9022, 0.9022, 0.9022, 0.9022])

# %%
plt.plot(range(30), mean_op_rf_christine)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru christine')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_las_christine.png')
plt.show()

# %%
plt.plot(range(50), mean_op_rf_kddc)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru kddc')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_las_kddc.png')
plt.show()

# %% [markdown]
# ### Wykresy dla CatBoost

# %%
catb_score_kddc = np.load('score_catboost_kddc.npy',allow_pickle=True).item()
catb_score_click = np.load('score_catboost_click.npy',allow_pickle=True).item()
catb_score_santa_nder = np.load('score_catboost_santa_nder.npy',allow_pickle=True).item()

# %%
mean_cb_christine = np.load('score_catboost_christine.npy')
mean_cb_click = catb_score_click['mean_test_score']
mean_cb_santa_nder = catb_score_santa_nder['mean_test_score']
mean_cb_kddc = catb_score_kddc['mean_test_score']

# %%
cb_score = pd.DataFrame([mean_cb_click,mean_cb_santa_nder,mean_cb_christine,mean_cb_kddc ])
print(cb_score)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.832207  0.834134  0.832432  0.831581  0.829103  0.833509  0.831681
# 1       NaN  0.904700  0.900400  0.900400  0.909100  0.900700  0.901100
# 2  0.816547  0.821127  0.818198  0.819125  0.818195  0.825557  0.819960
# 3  0.796900  0.786560  0.798093  0.803060  0.782591  0.790340  0.801072
#
#          7         8         9   ...        40        41        42        43  \
# 0  0.831756  0.833734  0.833709  ...  0.828577  0.833058  0.832682  0.831581
# 1  0.900500  0.907800  0.900400  ...  0.906600  0.908100  0.900400  0.900400
# 2  0.816827  0.822468  0.816337  ...  0.819784  0.823011  0.821085  0.818065
# 3  0.800277  0.784380  0.798091  ...  0.785770  0.778616  0.798490  0.796502
#
#          44        45        46        47        48        49
# 0  0.835361  0.835361  0.833083  0.834685  0.833258  0.831581
# 1  0.902200  0.902200  0.900400  0.903600  0.900400  0.900400
# ...

# %%
mean_cb = cb_score.mean()
which = np.where(mean_cb.max()==cb_score.mean())

# %%
params = np.array(catb_score_click['params'])

# %%
default = params[which]
def_score = mean_cb.max()

# %%
print(default)
print(def_score)
# Out:
# [{'learning_rate': 0.1, 'l2_leaf_reg': 3, 'iterations': 100, 'depth': 4, 'colsample_bylevel': 0.5, 'bagging_temperature': 0.1}]
# 0.8407019979337034

# %%
plt.boxplot([def_score-mean_cb])
plt.title('Tunowalność CatBoost dla metody Random Search')
plt.xlabel('CatBoost')
plt.ylabel('Różnica dokładności najlepszej kombinacji i reszty')
plt.xticks([])
plt.savefig('tunowalnosc_cb_rs.png')
plt.show()

# %%
diff = mean_cb_santa_nder-def_score

# %%
plt.boxplot([mean_cb_click-def_score,diff[1:],mean_cb_christine-def_score,mean_cb_kddc-def_score],labels=['click','santander','christine','kddc'])
plt.title('Rozkład różnicy dokładności dla metody Random Search')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Różnica dokładności')
plt.savefig('cb_df.png')
plt.show()

# %%
plt.boxplot([mean_cb_click,mean_cb_santa_nder[1:],mean_cb_christine,mean_cb_kddc],labels=['click','santander','christine','kddc'])
plt.title('Rozkład miary dopasowania dla metody Random Search')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Wartość miary dopasowania')
plt.savefig('cb_score.png')
plt.show()

# %%
op_cb_score_kddc = np.load('bs_cb_results_kddc.npy',allow_pickle=True).item()
op_cb_score_click = np.load('bs_cb_results_click.npy',allow_pickle=True).item()
op_cb_score_santa_nder = np.load('bs_cb_results_santa_nder.npy',allow_pickle=True).item()

# %%
mean_op_cb_christine = np.load('bs_cb_results_christine.npy',allow_pickle=True)
mean_op_cb_click = op_cb_score_click['mean_test_score']
mean_op_cb_santa_nder = op_cb_score_santa_nder['mean_test_score']
mean_op_cb_kddc = op_cb_score_kddc['mean_test_score']

# %%
op_cb_score = pd.DataFrame([mean_op_cb_click,mean_op_cb_santa_nder,mean_op_cb_christine,mean_op_cb_kddc ])

# %%
print(op_cb_score)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.835386  0.833458  0.834810  0.831581  0.835136  0.833934  0.835136
# 1  0.901200  0.900900  0.905000  0.900900  0.902800  0.901600  0.906700
# 2  0.858436  0.849966  0.855611  0.856957  0.859435  0.859435  0.859801
# 3  0.792924  0.795905  0.798886  0.803855  0.793122  0.804450  0.790736
#
#          7         8         9   ...        40        41        42        43  \
# 0  0.833383  0.833433  0.835211  ...  0.833308  0.832532  0.833283  0.831581
# 1  0.900900  0.900900  0.902600  ...  0.908800  0.908800  0.908600  0.907900
# 2  0.853296  0.856936  0.855896  ...       NaN       NaN       NaN       NaN
# 3  0.795308  0.799085  0.792129  ...  0.802068  0.804253  0.805445  0.805445
#
#          44        45        46        47        48        49
# 0  0.833383  0.834685  0.834635  0.835086  0.822569  0.833609
# 1  0.900900  0.908600  0.900900  0.902500  0.900900  0.900900
# ...

# %%
plt.boxplot([def_score-op_cb_score.mean()])
plt.title('Tunowalność CatBoost dla metody bayesowskiej')
plt.xlabel('CatBoost')
plt.ylabel('Różnica dokładności najlepszej kombinacji i reszty')
plt.xticks([])
plt.savefig('tunowalnosc_cb_bayes.png')
plt.show()

# %%
plt.boxplot([mean_op_cb_click-def_score,mean_op_cb_santa_nder-def_score,mean_op_cb_christine-def_score,mean_op_cb_kddc-def_score ],labels=['click','santander','christine','kddc'])
plt.title('Rozkład różnicy dokładności dla metody bayesowskiej')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Różnica dokładności')
plt.savefig('bp_cb_df_op.png')
plt.show()

# %%
plt.boxplot([mean_op_cb_click,mean_op_cb_santa_nder,mean_op_cb_christine,mean_op_cb_kddc],labels=['click','santander','christine','kddc'])
plt.title('Rozkład miary dopasowania dla metody bayesowskiej')
plt.xlabel('Nazwy zbiorów')
plt.ylabel('Wartość miary dopasowania')
plt.savefig('bp_cb_bayes.png')
plt.show()

# %%
plt.plot(range(50), mean_op_cb_click)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru click')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_cb_click.png')
plt.show()

# %%
plt.plot(range(50), mean_op_cb_santa_nder)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru santander')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_cb_santa.png')
plt.show()

# %%
plt.plot(range(50), mean_op_cb_kddc)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru kddc')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_cb_kddc.png')
plt.show()

# %%
plt.plot(range(30), mean_op_cb_christine)
plt.title('Zbieżność optymalizacji bayesowskiej dla zbioru christine')
plt.xlabel('Liczba iteracji')
plt.ylabel('Wartość dokładności')
plt.savefig('zbieznosc_cb_christine.png')
plt.show()
