# %%
#logistic
(39,
 0.6918432689870089,
 {'model__solver': 'newton-cholesky',
  'model__multi_class': 'auto',
  'model__max_iter': 50,
  'model__fit_intercept': False,
  'model__C': 0.001})
# Out:
# (39,
#  0.6918432689870089,
#  {'model__solver': 'newton-cholesky',
#   'model__multi_class': 'auto',
#   'model__max_iter': 50,
#   'model__fit_intercept': False,
#   'model__C': 0.001})

# %%
# extra
(59,
 0.6918432689870089,
 {'model__bootstrap': True,
  'model__criterion': 'log_loss',
  'model__max_depth': 15,
  'model__max_features': 'log2',
  'model__min_impurity_decrease': 0.1,
  'model__min_samples_leaf': 45,
  'model__min_samples_split': 41,
  'model__min_weight_fraction_leaf': 0.10958925226022204,
  'model__n_estimators': 183},)
# Out:
# (59,
#  0.696225180157817,
#  {'model__bootstrap': True,
#   'model__criterion': 'log_loss',
#   'model__max_depth': 14,
#   'model__max_features': 'log2',
#   'model__min_impurity_decrease': 0.0,
#   'model__min_samples_leaf': 8,
#   'model__min_samples_split': 19,
#   'model__min_weight_fraction_leaf': 0.1,
#   'model__n_estimators': 100})

# %%
# knn
(39,
 0.8169157415227617,
 {'model__algorithm': 'auto',
  'model__leaf_size': 33,
  'model__n_neighbors': 14,
  'model__weights': 'distance'},)
# Out:
# (39,
#  0.8066710498821122,
#  {'model__algorithm': 'auto',
#   'model__leaf_size': 33,
#   'model__n_neighbors': 14,
#   'model__weights': 'distance'})

# %%
import numpy as np

# %%
SN = np.mean([ 0.6918432689870089, 0.696225180157817, 0.8066710498821122])
SN
# Out:
# 0.7315798330089794

# %%
# knn tunability
mean_test = [0.7872867659067808,
  0.7916071235792588,
  0.7922305844257869,
  0.7987109474938656,
  0.8059901960967937,
  0.8104463117345413,
  0.8048401119842093,
  0.8067273242764861,
  0.8018599434977051,
  0.8075816426169783,
  0.7950105537522643,
  0.8064068627634603,
  0.8067273242764861,
  0.8104463117345413,
  0.8022596197616533,
  0.8092572046844927,
  0.8107401345965306,
  0.8048401119842093,
  0.808774621513731,
  0.8084184773508718,
  0.8092572046844927,
  0.8067273242764861,
  0.7939252622969354,
  0.8067273242764861,
  0.8092388320133496,
  0.7916141263803793,
  0.8144763741975548,
  0.7950080029266253,
  0.8069199439169825,
  0.8018599434977051,
  0.7950080029266253,
  0.7943454303641623,
  0.7941737190183706,
  0.8104463117345413,
  0.7920307930470459,
  0.8064051698749412,
  0.8084149759503116,
  0.7993564420971448,
  0.8104676699878445,
  0.8169157415227617]

diff_knn = [x - SN for x in mean_test]
diff_knn
# Out:
# [0.055706932897801376,
#  0.060027290570279335,
#  0.060650751416807425,
#  0.06713111448488618,
#  0.07441036308781424,
#  0.07886647872556185,
#  0.07326027897522991,
#  0.07514749126750664,
#  0.07028011048872562,
#  0.07600180960799885,
#  0.06343072074328482,
#  0.07482702975448086,
#  0.07514749126750664,
#  0.07886647872556185,
#  0.07067978675267383,
#  0.07767737167551325,
#  0.07916030158755116,
#  0.07326027897522991,
#  0.07719478850475159,
#  0.07683864434189236,
#  0.07767737167551325,
#  0.07514749126750664,
#  0.062345429287955945,
#  0.07514749126750664,
#  0.07765899900437012,
#  0.06003429337139987,
#  0.08289654118857537,
#  0.06342816991764588,
#  0.07534011090800308,
#  0.07028011048872562,
#  0.06342816991764588,
#  0.06276559735518283,
#  0.0625938860093912,
#  0.07886647872556185,
#  0.06045096003806649,
#  0.07482533686596171,
#  0.0768351429413322,
#  0.06777660908816541,
#  0.07888783697886503,
#  0.08533590851378225]

# %%
#logistic
mean_test_logistic = [0.821201368192219,
  0.8237817054550729,
  0.8237817054550729,
  0.821201368192219,
  0.6918432689870089,
  0.8234522122523539,
  0.8031019857463177,
  0.6918432689870089,
  0.8237817054550729,
  0.7991426202375884,
  0.6961929215126805,
  0.6918432689870089,
  0.821201368192219,
  0.795225800086128,
  0.7864333088008728,
  0.8234522122523539,
  0.8179326756692282,
  0.8237817054550729,
  0.8031019857463177,
  0.7993039105601691,
  0.6918432689870089,
  0.8234522122523539,
  0.6918432689870089,
  0.6918432689870089,
  0.8179326756692282,
  0.6918432689870089,
  0.8004241402178625,
  0.6961929215126805,
  0.795225800086128,
  0.8004241402178625,
  0.7991426202375884,
  0.6918432689870089,
  0.7000687837157715,
  0.8031019857463177,
  0.8004241402178625,
  0.7000687837157715,
  0.7864333088008728,
  0.6918432689870089,
  0.795225800086128,
  0.6918432689870089]

diff_logistic = [x - SN for x in mean_test_logistic]
diff_logistic
# Out:
# [0.08962153518323956,
#  0.09220187244609346,
#  0.09220187244609346,
#  0.08962153518323956,
#  -0.039736564021970566,
#  0.09187237924337444,
#  0.07152215273733831,
#  -0.039736564021970566,
#  0.09220187244609346,
#  0.06756278722860898,
#  -0.03538691149629891,
#  -0.039736564021970566,
#  0.08962153518323956,
#  0.06364596707714854,
#  0.05485347579189337,
#  0.09187237924337444,
#  0.08635284266024879,
#  0.09220187244609346,
#  0.07152215273733831,
#  0.0677240775511897,
#  -0.039736564021970566,
#  0.09187237924337444,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  0.08635284266024879,
#  -0.039736564021970566,
#  0.06884430720888302,
#  -0.03538691149629891,
#  0.06364596707714854,
#  0.06884430720888302,
#  0.06756278722860898,
#  -0.039736564021970566,
#  -0.031511049293207916,
#  0.07152215273733831,
#  0.06884430720888302,
#  -0.031511049293207916,
#  0.05485347579189337,
#  -0.039736564021970566,
#  0.06364596707714854,
#  -0.039736564021970566]

# %%
mean_test_extra = [0.6918432689870089,
  0.743175987567799,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6920055965463907,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.782437271523601,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089,
  0.6918432689870089]
diff_extra = [x - SN for x in mean_test_extra ]
diff_extra
# Out:
# [-0.039736564021970566,
#  0.011596154558819571,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.03957423646258873,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  0.050857438514621545,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566,
#  -0.039736564021970566]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('_mpl-gallery')

# plot
fig, ax = plt.subplots(figsize=(10,6))
VP = ax.boxplot([diff_knn, diff_extra, diff_logistic], positions=[1, 2, 3], labels=['KNeighborsClassifier', 'ExtraTreesClassifier', 'LogisticRegression'], widths=0.6, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 3},
                capprops={"color": "C0", "linewidth": 3})


ax.set_xlabel('Algorithm', fontsize=14)  # Add X-axis label with custom font size
ax.set_ylabel('Performance difference', fontsize=14)  # Add Y-axis label with custom font size
ax.set_title('Tunability of algorithms - RandomizedSearchCV', fontsize=16)   # Add plot title with custom font size

# Adjust font size of tick labels
ax.tick_params(axis='both', labelsize=12)

# Set the size of the figure
fig.set_size_inches(10, 6)

plt.show()
