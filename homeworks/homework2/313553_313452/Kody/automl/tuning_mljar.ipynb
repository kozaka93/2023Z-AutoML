# %%
import pandas as pd 

from sklearn.datasets import load_digits
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.model_selection import train_test_split

from supervised.automl import AutoML

from utils import load_train_data, load_train_labels, load_test_data

# %%
data = load_train_data()
labels = load_train_labels()

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.33, random_state=42)

# train models with AutoML
automl = AutoML(mode="Compete", eval_metric='accuracy', total_time_limit=3600*6)
automl.fit(X_train, y_train.ravel())

# compute the accuracy on test data
predictions = automl.predict_all(X_test)
print(predictions.head())
print("Test accuracy:", balanced_accuracy_score(y_test, predictions["label"].astype(int)))
# Out:
# AutoML directory: AutoML_2
# The task is binary_classification with evaluation metric accuracy
# AutoML will use algorithms: ['Decision Tree', 'Linear', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree accuracy 0.701493 trained in 0.67 seconds
# Adjust validation. Remove: 1_DecisionTree
# Validation strategy: 10-fold CV Shuffle,Stratify
# * Step simple_algorithms will try to check up to 4 models
# 1_DecisionTree accuracy 0.691791 trained in 3.29 seconds
# 2_DecisionTree accuracy 0.738806 trained in 3.55 seconds
# 3_DecisionTree accuracy 0.740299 trained in 3.64 seconds
# 4_Linear accuracy 0.547015 trained in 10.1 seconds
# * Step default_algorithms will try to check up to 6 models
# 5_Default_LightGBM accuracy 0.820896 trained in 35.47 seconds
# 6_Default_Xgboost accuracy 0.804478 trained in 20.72 seconds
# 7_Default_CatBoost accuracy 0.837313 trained in 17.71 seconds
# 8_Default_NeuralNetwork accuracy 0.557463 trained in 10.04 seconds
# 9_Default_RandomForest accuracy 0.790299 trained in 26.32 seconds
# 10_Default_ExtraTrees accuracy 0.758955 trained in 14.08 seconds
# * Step not_so_random will try to check up to 54 models
# 20_LightGBM accuracy 0.808209 trained in 5.62 seconds
# 11_Xgboost accuracy 0.771642 trained in 15.7 seconds
# 29_CatBoost accuracy 0.859701 trained in 133.92 seconds
# 38_RandomForest accuracy 0.779851 trained in 21.92 seconds
# 47_ExtraTrees accuracy 0.735821 trained in 16.38 seconds
# 56_NeuralNetwork accuracy 0.576119 trained in 12.49 seconds
# 21_LightGBM accuracy 0.823881 trained in 9.73 seconds
# 12_Xgboost accuracy 0.799254 trained in 26.58 seconds
# 30_CatBoost accuracy 0.855224 trained in 56.24 seconds
# 39_RandomForest accuracy 0.801493 trained in 50.37 seconds
# 48_ExtraTrees accuracy 0.821642 trained in 23.49 seconds
# 57_NeuralNetwork accuracy 0.579851 trained in 21.55 seconds
# 22_LightGBM accuracy 0.821642 trained in 10.66 seconds
# 13_Xgboost accuracy 0.697761 trained in 11.09 seconds
# 31_CatBoost accuracy 0.842537 trained in 34.95 seconds
# 40_RandomForest accuracy 0.74403 trained in 26.66 seconds
# 49_ExtraTrees accuracy 0.698507 trained in 18.6 seconds
# 58_NeuralNetwork accuracy 0.572388 trained in 16.47 seconds
# 23_LightGBM accuracy 0.817164 trained in 19.01 seconds
# 14_Xgboost accuracy 0.620149 trained in 8.87 seconds
# 32_CatBoost accuracy 0.837313 trained in 56.72 seconds
# 41_RandomForest accuracy 0.796269 trained in 41.93 seconds
# 50_ExtraTrees accuracy 0.796269 trained in 19.85 seconds
# 59_NeuralNetwork accuracy 0.586567 trained in 14.23 seconds
# 24_LightGBM accuracy 0.81194 trained in 9.74 seconds
# 15_Xgboost accuracy 0.65 trained in 11.44 seconds
# 33_CatBoost accuracy 0.840299 trained in 66.0 seconds
# 42_RandomForest accuracy 0.745522 trained in 26.84 seconds
# 51_ExtraTrees accuracy 0.712687 trained in 18.33 seconds
# 60_NeuralNetwork accuracy 0.572388 trained in 17.0 seconds
# 25_LightGBM accuracy 0.833582 trained in 17.36 seconds
# 16_Xgboost accuracy 0.676866 trained in 13.31 seconds
# 34_CatBoost accuracy 0.786567 trained in 18.95 seconds
# 43_RandomForest accuracy 0.806716 trained in 52.16 seconds
# 52_ExtraTrees accuracy 0.827612 trained in 25.32 seconds
# 61_NeuralNetwork accuracy 0.570149 trained in 17.79 seconds
# 26_LightGBM accuracy 0.820149 trained in 11.76 seconds
# 17_Xgboost accuracy 0.710448 trained in 19.81 seconds
# 35_CatBoost accuracy 0.866418 trained in 53.09 seconds
# 44_RandomForest accuracy 0.79403 trained in 39.68 seconds
# 53_ExtraTrees accuracy 0.789552 trained in 23.23 seconds
# 62_NeuralNetwork accuracy 0.567164 trained in 16.34 seconds
# 27_LightGBM accuracy 0.825373 trained in 14.52 seconds
# 18_Xgboost accuracy 0.652239 trained in 14.73 seconds
# 36_CatBoost accuracy 0.846269 trained in 92.85 seconds
# 45_RandomForest accuracy 0.78806 trained in 29.55 seconds
# 54_ExtraTrees accuracy 0.745522 trained in 21.48 seconds
# 63_NeuralNetwork accuracy 0.521642 trained in 19.63 seconds
# 28_LightGBM accuracy 0.819403 trained in 12.99 seconds
# 19_Xgboost accuracy 0.802985 trained in 34.83 seconds
# 37_CatBoost accuracy 0.861194 trained in 106.5 seconds
# 46_RandomForest accuracy 0.784328 trained in 33.63 seconds
# 55_ExtraTrees accuracy 0.774627 trained in 24.06 seconds
# 64_NeuralNetwork accuracy 0.578358 trained in 18.14 seconds
# * Step golden_features will try to check up to 3 models
# None 50
# Add Golden Feature: feature_249_ratio_feature_443
# Add Golden Feature: feature_443_ratio_feature_249
# Add Golden Feature: feature_98_diff_feature_183
# Add Golden Feature: feature_193_diff_feature_468
# Add Golden Feature: feature_403_sum_feature_206
# Add Golden Feature: feature_424_diff_feature_446
# Add Golden Feature: feature_228_diff_feature_275
# Add Golden Feature: feature_66_ratio_feature_84
# Add Golden Feature: feature_84_ratio_feature_66
# Add Golden Feature: feature_394_sum_feature_359
# Add Golden Feature: feature_173_diff_feature_232
# Add Golden Feature: feature_481_multiply_feature_165
# Add Golden Feature: feature_481_sum_feature_165
# Add Golden Feature: feature_66_ratio_feature_223
# Add Golden Feature: feature_249_multiply_feature_49
# Add Golden Feature: feature_457_multiply_feature_75
# Add Golden Feature: feature_331_ratio_feature_354
# Add Golden Feature: feature_354_ratio_feature_331
# Add Golden Feature: feature_155_ratio_feature_167
# Add Golden Feature: feature_167_ratio_feature_155
# Add Golden Feature: feature_391_sum_feature_40
# Add Golden Feature: feature_165_diff_feature_455
# Add Golden Feature: feature_53_diff_feature_478
# Add Golden Feature: feature_345_diff_feature_473
# Add Golden Feature: feature_345_sum_feature_274
# Add Golden Feature: feature_170_sum_feature_59
# Add Golden Feature: feature_110_diff_feature_130
# Add Golden Feature: feature_322_sum_feature_153
# Add Golden Feature: feature_223_ratio_feature_66
# Add Golden Feature: feature_381_diff_feature_424
# Add Golden Feature: feature_181_sum_feature_8
# Add Golden Feature: feature_277_diff_feature_284
# Add Golden Feature: feature_128_sum_feature_1
# Add Golden Feature: feature_351_sum_feature_145
# Add Golden Feature: feature_157_diff_feature_252
# Add Golden Feature: feature_289_sum_feature_122
# Add Golden Feature: feature_476_multiply_feature_328
# Add Golden Feature: feature_291_sum_feature_56
# Add Golden Feature: feature_325_diff_feature_351
# Add Golden Feature: feature_443_sum_feature_261
# Add Golden Feature: feature_259_diff_feature_275
# Add Golden Feature: feature_181_ratio_feature_91
# Add Golden Feature: feature_91_ratio_feature_181
# Add Golden Feature: feature_91_diff_feature_181
# Add Golden Feature: feature_155_ratio_feature_265
# Add Golden Feature: feature_265_ratio_feature_155
# Add Golden Feature: feature_476_sum_feature_317
# Add Golden Feature: feature_165_diff_feature_356
# Add Golden Feature: feature_389_sum_feature_4
# Add Golden Feature: feature_352_sum_feature_228
# Created 50 Golden Features in 219.35 seconds.
# 35_CatBoost_GoldenFeatures accuracy 0.848507 trained in 280.35 seconds
# 37_CatBoost_GoldenFeatures accuracy 0.852239 trained in 129.41 seconds
# 29_CatBoost_GoldenFeatures accuracy 0.847761 trained in 152.17 seconds
# * Step insert_random_feature will try to check up to 1 model
# 35_CatBoost_RandomFeature accuracy 0.86194 trained in 336.36 seconds
# Drop features ['feature_443', 'feature_494', 'feature_337', 'feature_65', 'feature_157', 'feature_249', 'feature_244', 'feature_277', 'feature_47', 'feature_449', 'feature_446', 'feature_136', 'feature_302', 'feature_469', 'feature_39', 'feature_406', 'feature_489', 'feature_35', 'feature_421', 'feature_144', 'feature_385', 'feature_475', 'feature_218', 'feature_362', 'feature_101', 'feature_438', 'feature_265', 'feature_387', 'feature_482', 'feature_294', 'feature_113', 'feature_8', 'feature_215', 'feature_352', 'feature_9', 'feature_498', 'feature_331', 'feature_48', 'feature_480', 'feature_424', 'feature_491', 'feature_90', 'feature_348', 'feature_162', 'feature_196', 'feature_19', 'feature_248', 'feature_78', 'feature_6', 'feature_304', 'feature_50', 'feature_194', 'feature_180', 'feature_355', 'feature_226', 'feature_102', 'feature_354', 'feature_86', 'feature_208', 'feature_310', 'feature_342', 'feature_135', 'feature_254', 'feature_14', 'feature_462', 'feature_283', 'feature_279', 'feature_467', 'feature_297', 'feature_427', 'feature_381', 'feature_496', 'feature_321', 'feature_177', 'feature_327', 'feature_464', 'feature_366', 'feature_341', 'feature_425', 'feature_127', 'feature_276', 'feature_85', 'feature_495', 'feature_396', 'feature_51', 'feature_95', 'feature_91', 'feature_305', 'feature_388', 'feature_461', 'feature_67', 'feature_66', 'feature_104', 'feature_68', 'feature_117', 'feature_103', 'feature_108', 'feature_109', 'feature_236', 'feature_175', 'feature_31', 'feature_30', 'feature_151', 'feature_33', 'feature_18', 'feature_20', 'feature_220', 'feature_21', 'feature_22', 'feature_23', 'feature_143', 'feature_25', 'feature_26', 'feature_111', 'feature_149', 'feature_167', 'feature_204', 'feature_110', 'feature_115', 'feature_112', 'feature_69', 'feature_70', 'feature_71', 'feature_72', 'feature_74', 'feature_75', 'feature_76', 'feature_77', 'feature_224', 'feature_79', 'feature_80', 'feature_81', 'feature_83', 'feature_97', 'feature_84', 'feature_87', 'feature_82', 'feature_98', 'feature_114', 'feature_100', 'feature_219', 'feature_116', 'feature_245', 'feature_141', 'feature_99', 'feature_119', 'feature_120', 'feature_121', 'feature_122', 'feature_123', 'feature_164', 'feature_125', 'feature_128', 'feature_130', 'feature_131', 'feature_17', 'feature_142', 'feature_13', 'feature_38', 'feature_193', 'feature_228', 'random_feature', 'feature_133', 'feature_132', 'feature_195', 'feature_37', 'feature_40', 'feature_183', 'feature_41', 'feature_42', 'feature_158', 'feature_44', 'feature_198', 'feature_45', 'feature_88', 'feature_230', 'feature_191', 'feature_152', 'feature_185', 'feature_176', 'feature_138', 'feature_179', 'feature_181', 'feature_201', 'feature_184', 'feature_147', 'feature_174', 'feature_227', 'feature_200', 'feature_225', 'feature_186', 'feature_187', 'feature_199', 'feature_189', 'feature_190', 'feature_213', 'feature_197', 'feature_222', 'feature_5', 'feature_169', 'feature_15', 'feature_239', 'feature_210', 'feature_2', 'feature_4', 'feature_221', 'feature_240', 'feature_214', 'feature_216', 'feature_139', 'feature_7', 'feature_202', 'feature_10', 'feature_11', 'feature_12', 'feature_155', 'feature_36', 'feature_238', 'feature_64', 'feature_52', 'feature_223', 'feature_53', 'feature_54', 'feature_56', 'feature_203', 'feature_57', 'feature_58', 'feature_212', 'feature_231', 'feature_171', 'feature_61', 'feature_62', 'feature_229', 'feature_173', 'feature_46', 'feature_247', 'feature_89', 'feature_92', 'feature_307', 'feature_308', 'feature_309', 'feature_258', 'feature_311', 'feature_290', 'feature_267', 'feature_269', 'feature_266', 'feature_270', 'feature_272', 'feature_273', 'feature_274', 'feature_275', 'feature_262', 'feature_280', 'feature_281', 'feature_306', 'feature_259', 'feature_261', 'feature_369', 'feature_448', 'feature_450', 'feature_451', 'feature_453', 'feature_459', 'feature_460', 'feature_364', 'feature_292', 'feature_303', 'feature_293', 'feature_295', 'feature_296', 'fea ...
# * Step features_selection will try to check up to 6 models
# 35_CatBoost_SelectedFeatures accuracy 0.879104 trained in 15.37 seconds
# 25_LightGBM_SelectedFeatures accuracy 0.86194 trained in 12.53 seconds
# 52_ExtraTrees_SelectedFeatures accuracy 0.853731 trained in 19.82 seconds
# 43_RandomForest_SelectedFeatures accuracy 0.843284 trained in 19.38 seconds
# 6_Default_Xgboost_SelectedFeatures accuracy 0.844776 trained in 14.41 seconds
# 59_NeuralNetwork_SelectedFeatures accuracy 0.821642 trained in 15.47 seconds
# * Step hill_climbing_1 will try to check up to 23 models
# 65_CatBoost_SelectedFeatures accuracy 0.880597 trained in 15.43 seconds
# 66_CatBoost accuracy 0.859701 trained in 64.74 seconds
# 67_LightGBM_SelectedFeatures accuracy 0.86194 trained in 13.57 seconds
# 68_CatBoost accuracy 0.854478 trained in 119.63 seconds
# 69_ExtraTrees_SelectedFeatures accuracy 0.844776 trained in 19.87 seconds
# 70_Xgboost_SelectedFeatures accuracy 0.839552 trained in 14.86 seconds
# 71_RandomForest_SelectedFeatures accuracy 0.837313 trained in 20.37 seconds
# 72_LightGBM accuracy 0.833582 trained in 17.84 seconds
# 73_ExtraTrees accuracy 0.821642 trained in 28.33 seconds
# 74_LightGBM accuracy 0.825373 trained in 19.03 seconds
# 75_LightGBM accuracy 0.825373 trained in 19.19 seconds
# 76_NeuralNetwork_SelectedFeatures accuracy 0.83209 trained in 16.93 seconds
# 77_NeuralNetwork_SelectedFeatures accuracy 0.813433 trained in 19.47 seconds
# 78_ExtraTrees accuracy 0.81194 trained in 26.59 seconds
# 79_RandomForest accuracy 0.80597 trained in 51.66 seconds
# 80_Xgboost accuracy 0.795522 trained in 33.58 seconds
# 81_Xgboost accuracy 0.798507 trained in 39.19 seconds
# 82_Xgboost accuracy 0.799254 trained in 42.68 seconds
# 83_RandomForest accuracy 0.805224 trained in 51.72 seconds
# 84_DecisionTree accuracy 0.628358 trained in 16.12 seconds
# 85_NeuralNetwork accuracy 0.571642 trained in 21.47 seconds
# 86_NeuralNetwork accuracy 0.558955 trained in 26.54 seconds
# 87_NeuralNetwork accuracy 0.566418 trained in 22.53 seconds
# * Step hill_climbing_2 will try to check up to 12 models
# 88_CatBoost_SelectedFeatures accuracy 0.877612 trained in 19.09 seconds
# 89_LightGBM_SelectedFeatures accuracy 0.86194 trained in 16.66 seconds
# 90_ExtraTrees_SelectedFeatures accuracy 0.850746 trained in 23.69 seconds
# 91_ExtraTrees_SelectedFeatures accuracy 0.842537 trained in 22.5 seconds
# 92_RandomForest_SelectedFeatures accuracy 0.848507 trained in 24.35 seconds
# 93_Xgboost_SelectedFeatures accuracy 0.840299 trained in 18.72 seconds
# 94_RandomForest_SelectedFeatures accuracy 0.83806 trained in 24.71 seconds
# 95_ExtraTrees accuracy 0.828358 trained in 34.06 seconds
# 96_RandomForest accuracy 0.8 trained in 62.17 seconds
# 97_DecisionTree accuracy 0.735075 trained in 18.63 seconds
# 98_DecisionTree accuracy 0.734328 trained in 18.77 seconds
# 99_DecisionTree accuracy 0.683582 trained in 18.63 seconds
# * Step boost_on_errors will try to check up to 1 model
# 65_CatBoost_SelectedFeatures_BoostOnErrors accuracy 0.873881 trained in 20.68 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble accuracy 0.881343 trained in 6.74 seconds
# * Step stack will try to check up to 59 models
# 65_CatBoost_SelectedFeatures_Stacked accuracy 0.891791 trained in 31.0 seconds
# 89_LightGBM_SelectedFeatures_Stacked accuracy 0.892537 trained in 19.36 seconds
# 52_ExtraTrees_SelectedFeatures_Stacked accuracy 0.88806 trained in 25.37 seconds
# 92_RandomForest_SelectedFeatures_Stacked accuracy 0.895522 trained in 29.23 seconds
# 6_Default_Xgboost_SelectedFeatures_Stacked accuracy 0.878358 trained in 22.94 seconds
# 76_NeuralNetwork_SelectedFeatures_Stacked accuracy 0.858209 trained in 24.94 seconds
# 35_CatBoost_SelectedFeatures_Stacked accuracy 0.887313 trained in 32.85 seconds
# 67_LightGBM_SelectedFeatures_Stacked accuracy 0.892537 trained in 20.2 seconds
# 90_ExtraTrees_SelectedFeatures_Stacked accuracy 0.886567 trained in 27.05 seconds
# 43_RandomForest_SelectedFeatures_Stacked accuracy 0.892537 trained in 29.4 seconds
# 93_Xgboost_SelectedFeatures_Stacked accuracy 0.879851 trained in 23.76 seconds
# 59_NeuralNetwork_SelectedFeatures_Stacked accuracy 0.855224 trained in 26.01 seconds
# 88_CatBoost_SelectedFeatures_Stacked accuracy 0.891045 trained in 32.18 seconds
# 25_LightGBM_SelectedFeatures_Stacked accuracy 0.892537 trained in 21.1 seconds
# 69_ExtraTrees_SelectedFeatures_Stacked accuracy 0.891045 trained in 26.9 seconds
# 94_RandomForest_SelectedFeatures_Stacked accuracy 0.89403 trained in 30.86 seconds
# 70_Xgboost_SelectedFeatures_Stacked accuracy 0.885821 trained in 25.29 seconds
# 77_NeuralNetwork_SelectedFeatures_Stacked accuracy 0.844776 trained in 27.93 seconds
# 35_CatBoost_Stacked accuracy 0.88806 trained in 71.8 seconds
# 25_LightGBM_Stacked accuracy 0.885821 trained in 25.67 seconds
# 91_ExtraTrees_SelectedFeatures_Stacked accuracy 0.88806 trained in 27.75 seconds
# 71_RandomForest_SelectedFeatures_Stacked accuracy 0.889552 trained in 30.75 seconds
# 6_Default_Xgboost_Stacked accuracy 0.873134 trained in 37.13 seconds
# 59_NeuralNetwork_Stacked accuracy 0.740299 trained in 31.01 seconds
# 37_CatBoost_Stacked accuracy 0.890299 trained in 136.7 seconds
# 72_LightGBM_Stacked accuracy 0.885821 trained in 26.37 seconds
# 95_ExtraTrees_Stacked accuracy 0.885075 trained in 35.99 seconds
# 43_RandomForest_Stacked accuracy 0.888806 trained in 59.66 seconds
# 19_Xgboost_Stacked accuracy 0.881343 trained in 41.48 seconds
# 57_NeuralNetwork_Stacked accuracy 0.786567 trained in 34.01 seconds
# 66_CatBoost_Stacked accuracy 0.888806 trained in 76.41 seconds
# 27_LightGBM_Stacked accuracy 0.885821 trained in 29.21 seconds
# 52_ExtraTrees_Stacked accuracy 0.888806 trained in 36.84 seconds
# 79_RandomForest_Stacked accuracy 0.88806 trained in 56.62 seconds
# 82_Xgboost_Stacked accuracy 0.867164 trained in 43.87 seconds
# 64_NeuralNetwork_Stacked accuracy 0.734328 trained in 34.71 seconds
# 29_CatBoost_Stacked accuracy 0.882836 trained in 167.94 seconds
# 74_LightGBM_Stacked accuracy 0.885821 trained in 30.19 seconds
# 73_ExtraTrees_Stacked accuracy 0.886567 trained in 37.69 seconds
# 83_RandomForest_Stacked accuracy 0.888806 trained in 51.61 seconds
# 12_Xgboost_Stacked accuracy 0.86791 trained in 40.09 seconds
# 56_NeuralNetwork_Stacked accuracy 0.749254 trained in 35.08 seconds
# 30_CatBoost_Stacked accuracy 0.890299 trained in 74.5 seconds
# 75_LightGBM_Stacked accuracy 0.885821 trained in 30.9 seconds
# 48_ExtraTrees_Stacked accuracy 0.885821 trained in 37.92 seconds
# 39_RandomForest_Stacked accuracy 0.887313 trained in 53.13 seconds
# 81_Xgboost_Stacked accuracy 0.876119 trained in 42.14 seconds
# 58_NeuralNetwork_Stacked accuracy 0.779104 trained in 38.68 seconds
# 68_CatBoost_Stacked accuracy 0.891045 trained in 135.92 seconds
# 21_LightGBM_Stacked accuracy 0.891791 trained in 31.46 seconds
# 78_ExtraTrees_Stacked accuracy 0.887313 trained in 38.42 seconds
# 96_RandomForest_Stacked accuracy 0.891045 trained in 63.0 seconds
# 80_Xgboost_Stacked accuracy 0.876119 trained in 43.11 seconds
# 60_NeuralNetwork_Stacked accuracy 0.770149 trained in 37.51 seconds
# 22_LightGBM_Stacked accuracy 0.88806 trained in 33.17 seconds
# 50_ExtraTrees_Stacked accuracy 0.88806 trained in 37.41 seconds
# 41_RandomForest_Stacked accuracy 0.889552 trained in 49.59 seconds
# 11_Xgboost_Stacked accuracy 0.875373 trained in 37.24 seconds
# 85_NeuralNetwork_Stacked accuracy 0.737313 trained in 35.97 seconds
# * Step ensemble_stacked will try to check up to 1 model
# Ensemble_Stacked accuracy 0.895522 trained in 15.65 seconds
# AutoML fit time: 6453.47 seconds
# AutoML best model: 92_RandomForest_SelectedFeatures_Stacked
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#    prediction_-1  prediction_1  label
# 0       0.002614      0.997386      1
# 1       0.969189      0.030811     -1
# 2       0.849194      0.150806     -1
# 3       0.973407      0.026593     -1
# 4       0.986324      0.013676     -1
# Test accuracy: 0.8636497208345577

# %%
automl = AutoML(results_path="AutoML_2")
X_test = load_test_data()

y_pred_1 = automl.predict_proba(X_test)
# Out:
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:444: UserWarning: X has feature names, but StandardScaler was fitted without feature names
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...
#
# /home/dawid/anaconda3/envs/automl/lib/python3.7/site-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - 11_Xgboost_prediction
# - 12_Xgboost_prediction
# - 19_Xgboost_prediction
# - 1_DecisionTree_prediction
# - 21_LightGBM_prediction
# - ...
# Feature names seen at fit time, yet now missing:
# - 11_Xgboost_prediction_0_for_-1_1_for_1
# - 12_Xgboost_prediction_0_for_-1_1_for_1
# - 19_Xgboost_prediction_0_for_-1_1_for_1
# - 1_DecisionTree_prediction_0_for_-1_1_for_1
# - 21_LightGBM_prediction_0_for_-1_1_for_1
# - ...

# %%
with open('artificial_test.label', 'w') as f:
    for y_single in y_pred[:,1]:
        f.write(f'{y_single.item()}\n')
