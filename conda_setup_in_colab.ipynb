# %%
# !conda --version
# Out:
# /bin/bash: line 1: conda: command not found

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
	################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.12.0-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.12.0-Linux-x86_64.sh -b -f -p /usr/local/
# Out:
# --2023-11-08 12:57:03--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 104996770 (100M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh’
#
# Miniconda3-py37_4.1 100%[===================>] 100.13M   245MB/s    in 0.4s
#
# 2023-11-08 12:57:04 (245 MB/s) - ‘Miniconda3-py37_4.12.0-Linux-x86_64.sh’ saved [104996770/104996770]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py37h06a4308_2
#     - cffi==1.15.0=py37hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
#     - colorama==0.4.4=pyhd3eb1b0_0
#     - conda-content-trust==0.1.1=pyhd3eb1b0_0
#     - conda-package-handling==1.8.1=py37h7f8727e_0
#     - conda==4.12.0=py37h06a4308_0
#     - cryptography==36.0.0=py37h9ce1e76_0
#     - idna==3.3=pyhd3eb1b0_0
#     - ld_impl_linux-64==2.35.1=h7274673_9
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.3.0=h5101ec6_17
#     - libgomp==9.3.0=h5101ec6_17
#     - libstdcxx-ng==9.3.0=hd4cf53a_17
#     - ncurses==6.3=h7f8727e_2
#     - openssl==1.1.1n=h7f8727e_0
#     - pip==21.2.2=py37h06a4308_0
#     - pycosat==0.6.3=py37h27cfd23_0
#     - pycparser==2.21=pyhd3eb1b0_0
#     - pyopenssl==22.0.0=pyhd3eb1b0_0
#     - pysocks==1.7.1=py37_1
#     - python==3.7.13=h12debd9_0
#     - readline==8.1.2=h7f8727e_1
#     - requests==2.27.1=pyhd3eb1b0_0
#     - ruamel_yaml==0.15.100=py37h27cfd23_0
#     - setuptools==61.2.0=py37h06a4308_0
#     - six==1.16.0=pyhd3eb1b0_1
#     - sqlite==3.38.2=hc218d9a_0
#     - tk==8.6.11=h1ccaba5_0
#     - tqdm==4.63.0=pyhd3eb1b0_0
#     - urllib3==1.26.8=pyhd3eb1b0_0
#     - wheel==0.37.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.12=h7f8727e_1
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-4.5-1_gnu
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py37h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2022.3.29-h06a4308_1
#   certifi            pkgs/main/linux-64::certifi-2021.10.8-py37h06a4308_2
#   cffi               pkgs/main/linux-64::cffi-1.15.0-py37hd667e15_1
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   colorama           pkgs/main/noarch::colorama-0.4.4-pyhd3eb1b0_0
#   conda              pkgs/main/linux-64::conda-4.12.0-py37h06a4308_0
#   conda-content-tru~ pkgs/main/noarch::conda-content-trust-0.1.1-pyhd3eb1b0_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.8.1-py37h7f8727e_0
#   cryptography       pkgs/main/linux-64::cryptography-36.0.0-py37h9ce1e76_0
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.35.1-h7274673_9
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.3.0-h5101ec6_17
#   libgomp            pkgs/main/linux-64::libgomp-9.3.0-h5101ec6_17
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.3.0-hd4cf53a_17
#   ncurses            pkgs/main/linux-64::ncurses-6.3-h7f8727e_2
#   openssl            pkgs/main/linux-64::openssl-1.1.1n-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-21.2.2-py37h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h27cfd23_0
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-pyhd3eb1b0_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_1
#   python             pkgs/main/linux-64::python-3.7.13-h12debd9_0
#   readline           pkgs/main/linux-64::readline-8.1.2-h7f8727e_1
#   requests           pkgs/main/noarch::requests-2.27.1-pyhd3eb1b0_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.100-py37h27cfd23_0
#   setuptools         pkgs/main/linux-64::setuptools-61.2.0-py37h06a4308_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_1
#   sqlite             pkgs/main/linux-64::sqlite-3.38.2-hc218d9a_0
#   tk                 pkgs/main/linux-64::tk-8.6.11-h1ccaba5_0
#   tqdm               pkgs/main/noarch::tqdm-4.63.0-pyhd3eb1b0_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.8-pyhd3eb1b0_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.12-h7f8727e_1
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
# !which conda
# !conda --version
# Out:
# /usr/local/bin/conda
# conda 4.12.0

# %%
import sys
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.10/dist-packages
# Out:
# absl
# absl_py-1.4.0.dist-info
# adbc_driver_duckdb
# aiohttp
# aiohttp-3.8.6.dist-info
# aiosignal
# aiosignal-1.3.1.dist-info
# alabaster
# alabaster-0.7.13.dist-info
# albumentations
# albumentations-1.3.1.dist-info
# altair
# altair-4.2.2.dist-info
# anyio
# anyio-3.7.1.dist-info
# apiclient
# appdirs-1.4.4.dist-info
# appdirs.py
# apt
# apt_inst.cpython-310-x86_64-linux-gnu.so
# apt_inst-stubs
# apt_pkg.cpython-310-x86_64-linux-gnu.so
# apt_pkg-stubs
# aptsources
# argon2
# argon2_cffi-23.1.0.dist-info
# _argon2_cffi_bindings
# argon2_cffi_bindings-21.2.0.dist-info
# array_record
# array_record-0.5.0.dist-info
# arviz
# arviz-0.15.1.dist-info
# astropy
# astropy-5.3.4.dist-info
# astunparse
# astunparse-1.6.3.dist-info
# async_timeout
# async_timeout-4.0.3.dist-info
# atpublic-4.0.dist-info
# attr
# attrs
# attrs-23.1.0.dist-info
# audioread
# audioread-3.0.1.dist-info
# AUTHORS.rst
# autograd
# autograd-1.6.2.dist-info
# babel
# Babel-2.13.1.dist-info
# backcall
# backcall-0.2.0.dist-info
# beautifulsoup4-4.11.2.dist-info
# bidict
# bidict-0.22.1.dist-info
# bigframes
# bigframes-0.12.0.dist-info
# bin
# bleach
# bleach-6.1.0.dist-info
# blis
# blis-0.7.11.dist-info
# blosc2
# blosc2-2.0.0.dist-info
# bokeh
# bokeh-3.3.0.dist-info
# box
# bqplot
# bqplot-0.12.42.dist-info
# branca
# branca-0.6.0.dist-info
# bs4
# build
# build-1.0.3.dist-info
# cachecontrol
# cachecontrol-0.13.1.dist-info
# cachetools
# cachetools-5.3.2.dist-info
# catalogue
# catalogue-2.0.10.dist-info
# certifi
# certifi-2023.7.22.dist-info
# cffi
# cffi-1.16.0.dist-info
# _cffi_backend.cpython-310-x86_64-linux-gnu.so
# chardet
# chardet-5.2.0.dist-info
# charset_normalizer
# charset_normalizer-3.3.2.dist-info
# chex
# chex-0.1.7.dist-info
# clang
# click
# click-8.1.7.dist-info
# click_plugins
# click_plugins-1.1.1.dist-info
# cligj
# cligj-0.7.2.dist-info
# cloudpickle
# cloudpickle-2.2.1.dist-info
# cmake
# cmake-3.27.7.dist-info
# cmdstanpy
# cmdstanpy-1.2.0.dist-info
# colab_kernel_launcher.py
# colorcet
# colorcet-3.0.1.dist-info
# colorlover
# colorlover-0.3.0.dist-info
# colour-0.1.5.dist-info
# colour.py
# community
# community-1.0.0b1.dist-info
# confection
# confection-0.1.3.dist-info
# cons
# cons-0.4.6.dist-info
# contextlib2
# contextlib2-21.6.0.dist-info
# contourpy
# contourpy-1.2.0.dist-info
# cpuinfo
# cryptography
# cryptography-41.0.5.dist-info
# cufflinks
# cufflinks-0.17.3.dist-info
# cupy
# cupy_backends
# cupy_cuda11x-11.0.0.dist-info
# cupyx
# cv2
# _cvxcore.cpython-310-x86_64-linux-gnu.so
# cvxopt
# cvxopt-1.3.2.dist-info
# cvxopt.libs
# cvxpy
# cvxpy-1.3.2.dist-info
# cycler
# cycler-0.12.1.dist-info
# cymem
# cymem-2.0.8.dist-info
# Cython
# Cython-3.0.5.dist-info
# cython.py
# dask
# dask-2023.8.1.dist-info
# datascience
# datascience-0.17.6.dist-info
# dateutil
# db_dtypes
# db_dtypes-1.1.1.dist-info
# debugpy
# debugpy-1.6.6.dist-info
# decorator-4.4.2.dist-info
# decorator.py
# defusedxml
# defusedxml-0.7.1.dist-info
# diskcache
# diskcache-5.6.3.dist-info
# distributed
# distributed-2023.8.1.dist-info
# _distutils_hack
# distutils-precedence.pth
# dlib
# dlib-19.24.2.dist-info
# _dlib_pybind11.cpython-310-x86_64-linux-gnu.so
# dm_tree-0.1.8.dist-info
# doc
# docutils
# docutils-0.18.1.dist-info
# dopamine
# dopamine_rl-4.0.6.dist-info
# dot_parser.py
# duckdb
# duckdb-0.9.1.dist-info
# duckdb-stubs
# earthengine_api-0.1.377.dist-info
# easydict
# easydict-1.11.dist-info
# ecos
# ecos-2.0.12.dist-info
# _ecos.cpython-310-x86_64-linux-gnu.so
# editdistance
# editdistance-0.6.2.dist-info
# ee
# eerepr
# eerepr-0.0.4.dist-info
# en_core_web_sm
# en_core_web_sm-3.6.0.dist-info
# entrypoints-0.4.dist-info
# entrypoints.py
# erfa
# etils
# etils-1.5.2.dist-info
# etuples
# etuples-0.3.9.dist-info
# et_xmlfile
# et_xmlfile-1.1.0.dist-info
# exceptiongroup
# exceptiongroup-1.1.3.dist-info
# extension
# fastai
# fastai-2.7.13.dist-info
# fastcore
# fastcore-1.5.29.dist-info
# fastdownload
# fastdownload-0.0.7.dist-info
# fastjsonschema
# fastjsonschema-2.18.1.dist-info
# fastprogress
# fastprogress-1.0.3.dist-info
# fastrlock
# fastrlock-0.8.2.dist-info
# filelock
# filelock-3.13.1.dist-info
# fiona
# fiona-1.9.5.dist-info
# fiona.libs
# firebase_admin
# firebase_admin-5.3.0.dist-info
# flask
# Flask-2.2.5.dist-info
# flatbuffers
# flatbuffers-23.5.26.dist-info
# flax
# flax-0.7.4.dist-info
# folium
# folium-0.14.0.dist-info
# fontTools
# fonttools-4.44.0.dist-info
# frozendict
# frozendict-2.3.8.dist-info
# frozenlist
# frozenlist-1.4.0.dist-info
# fsspec
# fsspec-2023.6.0.dist-info
# functorch
# future
# future-0.18.3.dist-info
# gast
# gast-0.5.4.dist-info
# gcsfs
# gcsfs-2023.6.0.dist-info
# GDAL-3.4.3.dist-info
# gdown
# gdown-4.6.6.dist-info
# geemap
# geemap-0.28.2.dist-info
# gensim
# gensim-4.3.2.dist-info
# geocoder
# geocoder-1.38.1.dist-info
# geographiclib
# geographiclib-2.0.dist-info
# geopandas
# geopandas-0.13.2.dist-info
# geopy
# geopy-2.3.0.dist-info
# gin
# gin_config-0.5.0.dist-info
# glob2
# glob2-0.7.dist-info
# google
# google-2.0.3.dist-info
# googleapiclient
# google_api_core-2.11.1.dist-info
# google_api_core-2.11.1-py3.9-nspkg.pth
# google_api_python_client-2.84.0.dist-info
# googleapis_common_protos-1.61.0.dist-info
# googleapis_common_protos-1.61.0-py3.9-nspkg.pth
# google_auth-2.17.3.dist-info
# google_auth-2.17.3-py3.9-nspkg.pth
# google_auth_httplib2-0.1.1.dist-info
# google_auth_httplib2.py
# google_auth_oauthlib
# google_auth_oauthlib-1.0.0.dist-info
# google_cloud_bigquery-3.12.0.dist-info
# google_cloud_bigquery-3.12.0-py3.9-nspkg.pth
# google_cloud_bigquery_connection-1.12.1.dist-info
# google_cloud_bigquery_connection-1.12.1-py3.9-nspkg.pth
# google_cloud_bigquery_storage-2.22.0.dist-info
# google_cloud_bigquery_storage-2.22.0-py3.9-nspkg.pth
# google_cloud_core-2.3.3.dist-info
# google_cloud_core-2.3.3-py3.9-nspkg.pth
# google_cloud_datastore-2.15.2.dist-info
# google_cloud_datastore-2.15.2-py3.9-nspkg.pth
# google_cloud_firestore-2.11.1.dist-info
# google_cloud_firestore-2.11.1-py3.9-nspkg.pth
# google_cloud_functions-1.13.3.dist-info
# google_cloud_functions-1.13.3-py3.9-nspkg.pth
# google_cloud_iam-2.12.2.dist-info
# google_cloud_iam-2.12.2-py3.9-nspkg.pth
# google_cloud_language-2.9.1.dist-info
# google_cloud_language-2.9.1-py3.9-nspkg.pth
# google_cloud_resource_manager-1.10.4.dist-info
# google_cloud_resource_manager-1.10.4-py3.9-nspkg.pth
# google_cloud_storage-2.8.0.dist-info
# google_cloud_storage-2.8.0-py3.9-nspkg.pth
# google_cloud_translate-3.11.3.dist-info
# google_cloud_translate-3.11.3-py3.9-nspkg.pth
# google_colab-1.0.0.dist-info
# google_colab-1.0.0-py3.10-nspkg.pth
# google_crc32c
# google_crc32c-1.5.0.dist-info
# google_crc32c.libs
# google_drive_downloader
# googledrivedownloader-0.4.dist-info
# google_pasta-0.2.0.dist-info
# google_resumable_media-2.6.0.dist-info
# googlesearch
# graphviz
# graphviz-0.20.1.dist-info
# greenlet
# greenlet-3.0.1.dist-info
# grpc
# grpc_google_iam_v1-0.12.6.dist-info
# grpc_google_iam_v1-0.12.6-py3.9-nspkg.pth
# grpcio-1.59.2.dist-info
# grpcio_status-1.48.2.dist-info
# grpc_status
# gspread
# gspread-3.4.2.dist-info
# gspread_dataframe-3.3.1.dist-info
# gspread_dataframe.py
# gym
# gym-0.25.2.dist-info
# gym_notices
# gym_notices-0.0.8.dist-info
# h5netcdf
# h5netcdf-1.2.0.dist-info
# h5py
# h5py-3.9.0.dist-info
# h5py.libs
# helper
# holidays
# holidays-0.35.dist-info
# holoviews
# holoviews-1.17.1.dist-info
# html5lib
# html5lib-1.1.dist-info
# httpimport-1.3.1.dist-info
# httpimport.py
# httplib2
# httplib2-0.22.0.dist-info
# humanize
# humanize-4.7.0.dist-info
# hyperopt
# hyperopt-0.2.7.dist-info
# ibis
# ibis_framework-6.2.0.dist-info
# idna
# idna-3.4.dist-info
# imageio
# imageio-2.31.6.dist-info
# imageio_ffmpeg
# imageio_ffmpeg-0.4.9.dist-info
# imagesize
# imagesize-1.4.1.dist-info
# imagesize.py
# imbalanced_learn-0.10.1.dist-info
# imblearn
# imgaug
# imgaug-0.4.0.dist-info
# importlib_metadata
# importlib_metadata-6.8.0.dist-info
# importlib_resources
# importlib_resources-6.1.0.dist-info
# imutils
# imutils-0.5.4.dist-info
# inflect
# inflect-7.0.0.dist-info
# iniconfig
# iniconfig-2.0.0.dist-info
# install
# install-1.3.5.dist-info
# intel_openmp-2023.2.0.dist-info
# ipyevents
# ipyevents-2.0.2.dist-info
# ipyfilechooser
# ipyfilechooser-0.6.0.dist-info
# ipykernel
# ipykernel-5.5.6.dist-info
# ipykernel_launcher.py
# ipyleaflet
# ipyleaflet-0.17.4.dist-info
# IPython
# ipython-7.34.0.dist-info
# ipython_genutils
# ipython_genutils-0.2.0.dist-info
# ipython_sql-0.5.0.dist-info
# ipytree
# ipytree-0.2.2.dist-info
# ipywidgets
# ipywidgets-7.7.1.dist-info
# isympy.py
# itsdangerous
# itsdangerous-2.1.2.dist-info
# jax
# jax-0.4.16.dist-info
# jaxlib
# jaxlib-0.4.16+cuda11.cudnn86.dist-info
# jieba
# jieba-0.42.1.dist-info
# jinja2
# Jinja2-3.1.2.dist-info
# joblib
# joblib-1.3.2.dist-info
# jsonpickle
# jsonpickle-3.0.2.dist-info
# jsonschema
# jsonschema-4.19.2.dist-info
# jsonschema_specifications
# jsonschema_specifications-2023.7.1.dist-info
# jupyter_client
# jupyter_client-6.1.12.dist-info
# jupyter_console
# jupyter_console-6.1.0.dist-info
# jupyter_core
# jupyter_core-5.5.0.dist-info
# jupyterlab_plotly
# jupyterlab_pygments
# jupyterlab_pygments-0.2.2.dist-info
# jupyterlab_widgets
# jupyterlab_widgets-3.0.9.dist-info
# jupyter.py
# jupyter_server
# jupyter_server-1.24.0.dist-info
# kaggle
# kaggle-1.5.16.dist-info
# kanren
# keras
# keras-2.14.0.dist-info
# kiwisolver
# kiwisolver-1.4.5.dist-info
# langcodes
# langcodes-3.3.0.dist-info
# lazy_loader
# lazy_loader-0.3.dist-info
# libclang-16.0.6.dist-info
# libfuturize
# libpasteurize
# librosa
# librosa-0.10.1.dist-info
# LICENSE
# lida
# lida-0.0.10.dist-info
# lightgbm
# lightgbm-4.1.0.dist-info
# linkify_it
# linkify_it_py-2.0.2.dist-info
# llmx
# llmx-0.0.15a0.dist-info
# llvmlite
# llvmlite-0.41.1.dist-info
# locket
# locket-1.0.0.dist-info
# logical_unification-0.4.6.dist-info
# lxml
# lxml-4.9.3.dist-info
# malloy
# malloy-2023.1064.dist-info
# markdown
# Markdown-3.5.1.dist-info
# markdown_it
# markdown_it_py-3.0.0.dist-info
# markupsafe
# MarkupSafe-2.1.3.dist-info
# matplotlib
# matplotlib-3.7.1.dist-info
# matplotlib-3.7.1-py3.10-nspkg.pth
# matplotlib_inline
# matplotlib_inline-0.1.6.dist-info
# matplotlib_venn
# matplotlib_venn-0.11.9.dist-info
# mdit_py_plugins
# mdit_py_plugins-0.4.0.dist-info
# mdurl
# mdurl-0.1.2.dist-info
# miniKanren-1.0.3.dist-info
# missingno
# missingno-0.5.2.dist-info
# mistune-0.8.4.dist-info
# mistune.py
# mizani
# mizani-0.9.3.dist-info
# mkl-2023.2.0.dist-info
# ml_dtypes
# ml_dtypes-0.2.0.dist-info
# mlxtend
# mlxtend-0.22.0.dist-info
# more_itertools
# more_itertools-10.1.0.dist-info
# moviepy
# moviepy-1.0.3.dist-info
# mpl_toolkits
# mpmath
# mpmath-1.3.0.dist-info
# msgpack
# msgpack-1.0.7.dist-info
# multidict
# multidict-6.0.4.dist-info
# multipledispatch
# multipledispatch-1.0.0.dist-info
# multitasking
# multitasking-0.0.11.dist-info
# murmurhash
# murmurhash-1.0.10.dist-info
# music21
# music21-9.1.0.dist-info
# natsort
# natsort-8.4.0.dist-info
# nbclassic
# nbclassic-1.0.0.dist-info
# nbclient
# nbclient-0.8.0.dist-info
# nbconvert
# nbconvert-6.5.4.dist-info
# nbformat
# nbformat-5.9.2.dist-info
# nest_asyncio-1.5.8.dist-info
# nest_asyncio.py
# networkx
# networkx-3.2.1.dist-info
# nibabel
# nibabel-4.0.2.dist-info
# nisext
# nltk
# nltk-3.8.1.dist-info
# notebook
# notebook-6.5.5.dist-info
# notebook_shim
# notebook_shim-0.2.3.dist-info
# numba
# numba-0.58.1.dist-info
# numbergen
# numexpr
# numexpr-2.8.7.dist-info
# numpy
# numpy-1.23.5.dist-info
# numpy.libs
# nvfuser
# oauth2client
# oauth2client-4.1.3.dist-info
# oauthlib
# oauthlib-3.2.2.dist-info
# opencv_contrib_python-4.8.0.76.dist-info
# opencv_contrib_python.libs
# opencv_python-4.8.0.76.dist-info
# opencv_python_headless-4.8.1.78.dist-info
# opencv_python_headless.libs
# opencv_python.libs
# OpenGL
# openpyxl
# openpyxl-3.1.2.dist-info
# OpenSSL
# optax
# optax-0.1.7.dist-info
# opt_einsum
# opt_einsum-3.3.0.dist-info
# orbax
# orbax_checkpoint-0.4.1.dist-info
# osgeo
# osgeo_utils
# osqp
# osqp-0.6.2.post8.dist-info
# osqppurepy
# packaging
# packaging-23.2.dist-info
# pandas
# pandas-1.5.3.dist-info
# pandas_datareader
# pandas_datareader-0.10.0.dist-info
# pandas_gbq
# pandas_gbq-0.17.9.dist-info
# pandas-stubs
# pandas_stubs-1.5.3.230304.dist-info
# pandocfilters-1.5.0.dist-info
# pandocfilters.py
# panel
# panel-1.3.1.dist-info
# param
# param-2.0.0.dist-info
# parso
# parso-0.8.3.dist-info
# parsy
# parsy-2.1.dist-info
# partd
# partd-1.4.1.dist-info
# past
# pasta
# pathlib-1.0.1.dist-info
# pathlib.py
# pathy
# pathy-0.10.3.dist-info
# patsy
# patsy-0.5.3.dist-info
# peewee-3.17.0.dist-info
# peewee.py
# pexpect
# pexpect-4.8.0.dist-info
# pickleshare-0.7.5.dist-info
# pickleshare.py
# PIL
# Pillow-9.4.0.dist-info
# Pillow.libs
# pip
# pip-23.1.2.dist-info
# piptools
# pip_tools-6.13.0.dist-info
# pkg_resources
# pkg_resources-stubs
# platformdirs
# platformdirs-3.11.0.dist-info
# playhouse
# plotly
# plotly-5.15.0.dist-info
# _plotly_future_
# _plotly_utils
# plotnine
# plotnine-0.12.3.dist-info
# pluggy
# pluggy-1.3.0.dist-info
# polars
# polars-0.17.3.dist-info
# pooch
# pooch-1.8.0.dist-info
# portpicker-1.5.2.dist-info
# portpicker.py
# prefetch_generator
# prefetch_generator-1.0.3.dist-info
# preshed
# preshed-3.0.9.dist-info
# prettytable
# prettytable-3.9.0.dist-info
# proglog
# proglog-0.1.10.dist-info
# progressbar
# progressbar2-4.2.0.dist-info
# prometheus_client
# prometheus_client-0.18.0.dist-info
# promise
# promise-2.3.dist-info
# prompt_toolkit
# prompt_toolkit-3.0.39.dist-info
# prophet
# prophet-1.1.5.dist-info
# prophet.libs
# proto
# protobuf-3.20.3.dist-info
# protobuf-3.20.3-py3.10-nspkg.pth
# proto_plus-1.22.3.dist-info
# psutil
# psutil-5.9.5.dist-info
# psycopg2
# psycopg2-2.9.9.dist-info
# ptyprocess
# ptyprocess-0.7.0.dist-info
# public
# pwiz.py
# py4j
# py4j-0.10.9.7.dist-info
# pyarrow
# pyarrow-9.0.0.dist-info
# pyasn1
# pyasn1-0.5.0.dist-info
# pyasn1_modules
# pyasn1_modules-0.3.0.dist-info
# __pycache__
# pycocotools
# pycocotools-2.0.7.dist-info
# pycparser
# pycparser-2.21.dist-info
# py_cpuinfo-9.0.0.dist-info
# pyct
# pyct-0.5.0.dist-info
# pydantic
# pydantic-1.10.13.dist-info
# pydata_google_auth
# pydata_google_auth-1.8.2.dist-info
# pydot-1.4.2.dist-info
# pydot_ng
# pydot_ng-2.0.0.dist-info
# pydotplus
# pydotplus-2.0.2.dist-info
# pydot.py
# pydrive
# PyDrive-1.3.1.dist-info
# pydrive2
# PyDrive2-1.6.3.dist-info
# pyerfa-2.0.1.1.dist-info
# pygame
# pygame-2.5.2.dist-info
# pygame.libs
# pygments
# Pygments-2.16.1.dist-info
# pylab.py
# pymc
# pymc-5.7.2.dist-info
# pymystem3
# pymystem3-0.2.0.dist-info
# PyOpenGL-3.1.7.dist-info
# pyOpenSSL-23.3.0.dist-info
# pyparsing
# pyparsing-3.1.1.dist-info
# pyperclip
# pyperclip-1.8.2.dist-info
# pyproj
# pyproj-3.6.1.dist-info
# pyproject_hooks
# pyproject_hooks-1.0.0.dist-info
# pyproj.libs
# py.py
# pyshp-2.3.1.dist-info
# PySocks-1.7.1.dist-info
# pytensor
# pytensor-2.14.2.dist-info
# _pytest
# pytest
# pytest-7.4.3.dist-info
# python_apt-0.0.0-py3.10.egg-info
# python_box-7.1.1.dist-info
# python_dateutil-2.8.2.dist-info
# python_louvain-0.16.dist-info
# python_slugify-8.0.1.dist-info
# python_utils
# python_utils-3.8.1.dist-info
# pytz
# pytz-2023.3.post1.dist-info
# pytz-stubs
# pyviz_comms
# pyviz_comms-3.0.0.dist-info
# PyWavelets-1.4.1.dist-info
# pywt
# pyximport
# PyYAML-6.0.1.dist-info
# pyzmq-23.2.1.dist-info
# pyzmq.libs
# qdldl-0.1.7.post0.dist-info
# qdldl.cpython-310-x86_64-linux-gnu.so
# qudida
# qudida-0.0.4.dist-info
# ratelim
# ratelim-0.1.6.dist-info
# README.md
# referencing
# referencing-0.30.2.dist-info
# regex
# regex-2023.6.3.dist-info
# requests
# requests-2.31.0.dist-info
# requests_oauthlib
# requests_oauthlib-1.3.1.dist-info
# requirements
# requirements_parser-0.5.0.dist-info
# rich
# rich-13.6.0.dist-info
# _rinterface_cffi_abi.py
# _rinterface_cffi_api.abi3.so
# rpds
# rpds_py-0.11.0.dist-info
# rpy2
# rpy2-3.4.2.dist-info
# rsa
# rsa-4.9.dist-info
# scikit_image-0.19.3.dist-info
# scikit_image.libs
# scikit_learn-1.2.2.dist-info
# scikit_learn.libs
# scipy
# scipy-1.11.3.dist-info
# scipy.libs
# scooby
# scooby-0.9.2.dist-info
# scs
# scs-3.2.3.dist-info
# _scs_direct.cpython-310-x86_64-linux-gnu.so
# _scs_indirect.cpython-310-x86_64-linux-gnu.so
# scs.libs
# seaborn
# seaborn-0.12.2.dist-info
# send2trash
# Send2Trash-1.8.2.dist-info
# setuptools
# setuptools-67.7.2.dist-info
# setuptools-stubs
# shapefile.py
# shapely
# shapely-2.0.2.dist-info
# shapely.libs
# six-1.16.0.dist-info
# six.py
# skimage
# sklearn
# sklearn_pandas
# sklearn_pandas-2.2.0.dist-info
# slugify
# smart_open
# smart_open-6.4.0.dist-info
# sniffio
# sniffio-1.3.0.dist-info
# snowballstemmer
# snowballstemmer-2.2.0.dist-info
# sockshandler.py
# socks.py
# sortedcontainers
# sortedcontainers-2.4.0.dist-info
# soundfile-0.12.1.dist-info
# _soundfile_data
# _soundfile.py
# soundfile.py
# soupsieve
# soupsieve-2.5.dist-info
# soxr
# soxr-0.3.7.dist-info
# spacy
# spacy-3.6.1.dist-info
# spacy_legacy
# spacy_legacy-3.0.12.dist-info
# spacy_loggers
# spacy_loggers-1.0.5.dist-info
# sphinx
# Sphinx-5.0.2.dist-info
# sphinxcontrib
# sphinxcontrib_applehelp-1.0.7.dist-info
# sphinxcontrib_devhelp-1.0.5.dist-info
# sphinxcontrib_htmlhelp-2.0.4.dist-info
# sphinxcontrib_jsmath-1.0.1.dist-info
# sphinxcontrib_jsmath-1.0.1-py3.7-nspkg.pth
# sphinxcontrib_qthelp-1.0.6.dist-info
# sphinxcontrib_serializinghtml-1.1.9.dist-info
# sql
# sqlalchemy
# SQLAlchemy-2.0.23.dist-info
# sqlglot
# sqlglot-17.16.2.dist-info
# sqlparse
# sqlparse-0.4.4.dist-info
# srsly
# srsly-2.4.8.dist-info
# stanio
# stanio-0.3.0.dist-info
# statsmodels
# statsmodels-0.14.0.dist-info
# sympy
# sympy-1.12.dist-info
# tables
# tables-3.8.0.dist-info
# tables.libs
# tabulate
# tabulate-0.9.0.dist-info
# tbb-2021.10.0.dist-info
# tblib
# tblib-3.0.0.dist-info
# tenacity
# tenacity-8.2.3.dist-info
# tensorboard
# tensorboard-2.14.1.dist-info
# tensorboard_data_server
# tensorboard_data_server-0.7.2.dist-info
# tensorflow
# tensorflow-2.14.0.dist-info
# tensorflow_datasets
# tensorflow_datasets-4.9.3.dist-info
# tensorflow_estimator
# tensorflow_estimator-2.14.0.dist-info
# tensorflow_gcs_config
# tensorflow_gcs_config-2.14.0.dist-info
# tensorflow_hub
# tensorflow_hub-0.15.0.dist-info
# tensorflow_io_gcs_filesystem
# tensorflow_io_gcs_filesystem-0.34.0.dist-info
# tensorflow_metadata
# tensorflow_metadata-1.14.0.dist-info
# tensorflow_probability
# tensorflow_probability-0.22.0.dist-info
# tensorstore
# tensorstore-0.1.45.dist-info
# termcolor
# termcolor-2.3.0.dist-info
# terminado
# terminado-0.17.1.dist-info
# textblob
# textblob-0.17.1.dist-info
# text_unidecode
# text_unidecode-1.3.dist-info
# tf_slim
# tf_slim-1.1.0.dist-info
# thinc
# thinc-8.1.12.dist-info
# third_party
# threadpoolctl-3.2.0.dist-info
# threadpoolctl.py
# tifffile
# tifffile-2023.9.26.dist-info
# tinycss2
# tinycss2-1.2.1.dist-info
# tlz
# toml
# toml-0.10.2.dist-info
# tomli
# tomli-2.0.1.dist-info
# toolz
# toolz-0.12.0.dist-info
# torch
# torch-2.1.0+cu118.dist-info
# torchaudio
# torchaudio-2.1.0+cu118.dist-info
# torchdata
# torchdata-0.7.0.dist-info
# torchgen
# torchsummary
# torchsummary-1.5.1.dist-info
# torchtext
# torchtext-0.16.0.dist-info
# torchvision
# torchvision-0.16.0+cu118.dist-info
# torchvision.libs
# tornado
# tornado-6.3.2.dist-info
# tqdm
# tqdm-4.66.1.dist-info
# traitlets
# traitlets-5.7.1.dist-info
# traittypes
# traittypes-0.2.1.dist-info
# tree
# triton
# triton-2.1.0.dist-info
# tweepy
# tweepy-4.14.0.dist-info
# typer
# typer-0.9.0.dist-info
# types_pytz-2023.3.1.1.dist-info
# types_setuptools-68.2.0.0.dist-info
# typing_extensions-4.5.0.dist-info
# typing_extensions.py
# tzlocal
# tzlocal-5.2.dist-info
# uc_micro
# uc_micro_py-1.0.2.dist-info
# unification
# uritemplate
# uritemplate-4.1.1.dist-info
# urllib3
# urllib3-2.0.7.dist-info
# vega_datasets
# vega_datasets-0.9.0.dist-info
# wasabi
# wasabi-1.1.2.dist-info
# wcwidth
# wcwidth-0.2.9.dist-info
# webcolors
# webcolors-1.13.dist-info
# webencodings
# webencodings-0.5.1.dist-info
# websocket
# websocket_client-1.6.4.dist-info
# werkzeug
# werkzeug-3.0.1.dist-info
# wheel
# wheel-0.41.3.dist-info
# widgetsnbextension
# widgetsnbextension-3.6.6.dist-info
# wordcloud
# wordcloud-1.9.2.dist-info
# wrapt
# wrapt-1.14.1.dist-info
# xarray
# xarray-2023.7.0.dist-info
# xarray_einstats
# xarray_einstats-0.6.0.dist-info
# xgboost
# xgboost-2.0.1.dist-info
# xgboost.libs
# xlrd
# xlrd-2.0.1.dist-info
# xxhash
# xxhash-3.4.1.dist-info
# xyzservices
# xyzservices-2023.10.1.dist-info
# _yaml
# yaml
# yarl
# yarl-1.9.2.dist-info
# yellowbrick
# yellowbrick-1.5.dist-info
# yfinance
# yfinance-0.2.31.dist-info
# zict
# zict-3.0.0.dist-info
# zipp
# zipp-3.17.0.dist-info
# zmq

# %%
import sys
sys.path.append("/usr/local/lib/python3.10/site-packages")

# %%
# !conda config --add channels conda-forge

# %%
# !conda env create --file environment.yaml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# Downloading and Extracting Packages
# nspr-4.35            | 244 KB    | : 100% 1.0/1 [00:00<00:00,  2.86it/s]
# numpy-1.26.0         | 10 KB     | : 100% 1.0/1 [00:00<00:00,  3.46it/s]
# readline-8.2         | 357 KB    | : 100% 1.0/1 [00:00<00:00,  3.35it/s]
# prompt_toolkit-3.0.3 | 7 KB      | : 100% 1.0/1 [00:00<00:00,  2.83it/s]
# typing-extensions-4. | 10 KB     | : 100% 1.0/1 [00:00<00:00,  2.40it/s]
# munkres-1.1.4        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  2.47it/s]
# gstreamer-1.14.1     | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  2.06it/s]
# libxkbcommon-1.0.1   | 590 KB    | : 100% 1.0/1 [00:00<00:00,  2.40it/s]
# libcurl-8.4.0        | 411 KB    | : 100% 1.0/1 [00:00<00:00,  2.33it/s]
# libsodium-1.0.18     | 366 KB    | : 100% 1.0/1 [00:00<00:00,  5.69it/s]
# intel-openmp-2023.1. | 17.1 MB   | : 100% 1.0/1 [00:01<00:00,  1.15s/it]
# prompt-toolkit-3.0.3 | 263 KB    | : 100% 1.0/1 [00:00<00:00,  2.21it/s]
# xz-5.4.2             | 642 KB    | : 100% 1.0/1 [00:00<00:00,  2.12it/s]
# snappy-1.1.9         | 636 KB    | : 100% 1.0/1 [00:00<00:00,  2.24it/s]
# qt-main-5.15.2       | 53.7 MB   | : 100% 1.0/1 [00:04<00:00,  4.66s/it]
# pyopenssl-23.2.0     | 121 KB    | : 100% 1.0/1 [00:00<00:00,  3.29it/s]
# libllvm14-14.0.6     | 33.4 MB   | : 100% 1.0/1 [00:01<00:00,  1.34s/it]
# libgomp-11.2.0       | 474 KB    | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# tzdata-2023c         | 116 KB    | : 100% 1.0/1 [00:00<00:00,  2.91it/s]
# pandas-2.0.3         | 14.7 MB   | : 100% 1.0/1 [00:01<00:00,  1.17s/it]
# backports.functools_ | 11 KB     | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
# pure_eval-0.2.2      | 14 KB     | : 100% 1.0/1 [00:00<00:00, 20.09it/s]
# mysql-5.7.24         | 60.0 MB   | : 100% 1.0/1 [00:05<00:00,  5.84s/it]
# pyaml-23.9.7         | 26 KB     | : 100% 1.0/1 [00:00<00:00,  2.47it/s]
# pexpect-4.8.0        | 48 KB     | : 100% 1.0/1 [00:00<00:00, 18.76it/s]
# arrow-cpp-11.0.0     | 10.2 MB   | : 100% 1.0/1 [00:00<00:00,  1.21it/s]
# freetype-2.12.1      | 626 KB    | : 100% 1.0/1 [00:00<00:00,  2.31it/s]
# re2-2022.04.01       | 210 KB    | : 100% 1.0/1 [00:00<00:00,  2.56it/s]
# packaging-23.1       | 100 KB    | : 100% 1.0/1 [00:00<00:00,  2.43it/s]
# jpeg-9e              | 262 KB    | : 100% 1.0/1 [00:00<00:00,  2.40it/s]
# libwebp-base-1.3.2   | 387 KB    | : 100% 1.0/1 [00:00<00:00,  2.33it/s]
# libthrift-0.15.0     | 4.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
# libtiff-4.5.1        | 533 KB    | : 100% 1.0/1 [00:00<00:00,  2.26it/s]
# backcall-0.2.0       | 13 KB     | : 100% 1.0/1 [00:00<00:00, 22.27it/s]
# libbrotlidec-1.0.9   | 31 KB     | : 100% 1.0/1 [00:00<00:00,  2.51it/s]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00,  2.48it/s]
# libxslt-1.1.37       | 266 KB    | : 100% 1.0/1 [00:00<00:00,  2.28it/s]
# nest-asyncio-1.5.6   | 10 KB     | : 100% 1.0/1 [00:00<00:00, 23.49it/s]
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:00<00:00,  2.40it/s]
# pcre-8.45            | 207 KB    | : 100% 1.0/1 [00:00<00:00,  2.36it/s]
# nss-3.89.1           | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.07it/s]
# numpy-base-1.26.0    | 8.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.01it/s]
# bottleneck-1.3.5     | 133 KB    | : 100% 1.0/1 [00:00<00:00,  2.38it/s]
# openssl-3.0.11       | 5.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.41it/s]
# cyrus-sasl-2.1.28    | 237 KB    | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# joblib-1.2.0         | 527 KB    | : 100% 1.0/1 [00:00<00:00,  3.02it/s]
# mkl-2023.1.0         | 171.6 MB  | : 100% 1.0/1 [00:07<00:00,  7.43s/it]
# python-3.11.5        | 32.7 MB   | : 100% 1.0/1 [00:02<00:00,  2.23s/it]
# glib-2.69.1          | 1.9 MB    | : 100% 1.0/1 [00:00<00:00,  2.09it/s]
# setuptools-68.0.0    | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.90it/s]
# libssh2-1.10.0       | 292 KB    | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# expat-2.5.0          | 172 KB    | : 100% 1.0/1 [00:00<00:00,  2.43it/s]
# comm-0.1.4           | 11 KB     | : 100% 1.0/1 [00:00<00:00,  2.38it/s]
# platformdirs-3.11.0  | 20 KB     | : 100% 1.0/1 [00:00<00:00,  2.38it/s]
# zeromq-4.3.4         | 351 KB    | : 100% 1.0/1 [00:00<00:00,  6.34it/s]
# libboost-1.73.0      | 13.8 MB   | : 100% 1.0/1 [00:04<00:00,  4.50s/it]
# scipy-1.11.1         | 21.9 MB   | : 100% 1.0/1 [00:02<00:00,  2.88s/it]
# libbrotlienc-1.0.9   | 264 KB    | : 100% 1.0/1 [00:00<00:00,  2.42it/s]
# gflags-2.2.2         | 126 KB    | : 100% 1.0/1 [00:00<00:00,  2.48it/s]
# abseil-cpp-20211102. | 1020 KB   | : 100% 1.0/1 [00:00<00:00,  1.84it/s]
# cryptography-41.0.3  | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.86it/s]
# pillow-9.4.0         | 875 KB    | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# libstdcxx-ng-11.2.0  | 4.7 MB    | : 100% 1.0/1 [00:00<00:00,  2.31it/s]
# ply-3.11             | 111 KB    | : 100% 1.0/1 [00:00<00:00,  3.35it/s]
# jedi-0.19.1          | 822 KB    | : 100% 1.0/1 [00:00<00:00,  1.35it/s]
# libgfortran-ng-11.2. | 20 KB     | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# backports-1.0        | 6 KB      | : 100% 1.0/1 [00:00<00:00,  3.11it/s]
# ipykernel-6.25.2     | 111 KB    | : 100% 1.0/1 [00:00<00:00,  2.56it/s]
# dbus-1.13.18         | 504 KB    | : 100% 1.0/1 [00:00<00:00,  2.96it/s]
# zlib-1.2.13          | 103 KB    | : 100% 1.0/1 [00:00<00:00,  3.44it/s]
# brotli-bin-1.0.9     | 19 KB     | : 100% 1.0/1 [00:00<00:00,  3.45it/s]
# libev-4.33           | 111 KB    | : 100% 1.0/1 [00:00<00:00,  3.34it/s]
# pip-23.2.1           | 3.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.97it/s]
# pyqt5-sip-12.11.0    | 82 KB     | : 100% 1.0/1 [00:00<00:00,  2.79it/s]
# numexpr-2.8.4        | 161 KB    | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# python_abi-3.11      | 5 KB      | : 100% 1.0/1 [00:00<00:00, 28.43it/s]
# libgfortran5-11.2.0  | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.64it/s]
# libxcb-1.15          | 505 KB    | : 100% 1.0/1 [00:00<00:00,  3.23it/s]
# sqlite-3.41.2        | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.97it/s]
# configparser-5.0.2   | 22 KB     | : 100% 1.0/1 [00:00<00:00,  3.45it/s]
# ptyprocess-0.7.0     | 16 KB     | : 100% 1.0/1 [00:00<00:00, 24.07it/s]
# pysocks-1.7.1        | 35 KB     | : 100% 1.0/1 [00:00<00:00,  3.46it/s]
# matplotlib-base-3.7. | 7.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.60it/s]
# krb5-1.20.1          | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.82it/s]
# pickleshare-0.7.5    | 9 KB      | : 100% 1.0/1 [00:00<00:00, 25.30it/s]
# debugpy-1.6.7        | 2.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.29it/s]
# jupyter_core-5.3.2   | 91 KB     | : 100% 1.0/1 [00:01<00:00,  1.55s/it]
# traitlets-5.11.2     | 106 KB    | : 100% 1.0/1 [00:00<00:00,  2.23it/s]
# libclang13-14.0.6    | 9.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.22it/s]
# utf8proc-2.6.1       | 308 KB    | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# fonttools-4.25.0     | 632 KB    | : 100% 1.0/1 [00:00<00:00,  2.14it/s]
# boost-cpp-1.73.0     | 16 KB     | : 100% 1.0/1 [00:00<00:00,  2.43it/s]
# openml-0.12.2        | 102 KB    | : 100% 1.0/1 [00:00<00:00,  1.49it/s]
# jupyter_client-8.3.1 | 103 KB    | : 100% 1.0/1 [00:00<00:00,  2.13it/s]
# libuuid-1.41.5       | 27 KB     | : 100% 1.0/1 [00:00<00:00,  2.61it/s]
# aws-c-event-stream-0 | 25 KB     | : 100% 1.0/1 [00:00<00:00,  2.46it/s]
# psutil-5.9.0         | 463 KB    | : 100% 1.0/1 [00:00<00:00,  2.26it/s]
# tbb-2021.8.0         | 1.6 MB    | : 100% 1.0/1 [00:00<00:00,  2.21it/s]
# mkl_fft-1.3.8        | 225 KB    | : 100% 1.0/1 [00:00<00:00,  2.37it/s]
# gst-plugins-base-1.1 | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.92it/s]
# asttokens-2.4.0      | 28 KB     | : 100% 1.0/1 [00:00<00:00,  2.42it/s]
# qt-webengine-5.15.9  | 53.8 MB   | : 100% 1.0/1 [00:02<00:00,  2.82s/it]
# kiwisolver-1.4.4     | 70 KB     | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
# requests-2.31.0      | 124 KB    | : 100% 1.0/1 [00:00<00:00,  2.38it/s]
# matplotlib-inline-0. | 12 KB     | : 100% 1.0/1 [00:00<00:00, 19.48it/s]
# typing_extensions-4. | 34 KB     | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# yaml-0.2.5           | 87 KB     | : 100% 1.0/1 [00:00<00:00, 11.16it/s]
# libprotobuf-3.20.3   | 2.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.97it/s]
# zipp-3.17.0          | 19 KB     | : 100% 1.0/1 [00:00<00:00,  2.43it/s]
# blas-1.0             | 1 KB      | : 100% 1.0/1 [00:00<00:00, 25.90it/s]
# cffi-1.15.1          | 283 KB    | : 100% 1.0/1 [00:00<00:00,  2.46it/s]
# importlib_metadata-6 | 9 KB      | : 100% 1.0/1 [00:00<00:00,  2.38it/s]
# libffi-3.4.4         | 142 KB    | : 100% 1.0/1 [00:00<00:00,  3.17it/s]
# wheel-0.41.2         | 145 KB    | : 100% 1.0/1 [00:00<00:00,  3.27it/s]
# ncurses-6.4          | 914 KB    | : 100% 1.0/1 [00:00<00:00,  1.97it/s]
# libedit-3.1.20221030 | 181 KB    | : 100% 1.0/1 [00:00<00:00,  3.29it/s]
# pyparsing-3.0.9      | 204 KB    | : 100% 1.0/1 [00:00<00:00,  3.35it/s]
# aws-checksums-0.1.11 | 48 KB     | : 100% 1.0/1 [00:00<00:00,  3.39it/s]
# liac-arff-2.5.0      | 17 KB     | : 100% 1.0/1 [00:01<00:00,  1.25s/it]
# libnghttp2-1.57.0    | 674 KB    | : 100% 1.0/1 [00:00<00:00,  3.32it/s]
# libclang-14.0.6      | 137 KB    | : 100% 1.0/1 [00:00<00:00,  3.44it/s]
# icu-58.2             | 10.5 MB   | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
# sip-6.6.2            | 487 KB    | : 100% 1.0/1 [00:00<00:00,  2.96it/s]
# tornado-6.3.2        | 865 KB    | : 100% 1.0/1 [00:00<00:00,  3.04it/s]
# python-dateutil-2.8. | 233 KB    | : 100% 1.0/1 [00:00<00:00,  3.39it/s]
# urllib3-1.26.16      | 256 KB    | : 100% 1.0/1 [00:00<00:00,  3.27it/s]
# qtwebkit-5.212       | 16.2 MB   | : 100% 1.0/1 [00:00<00:00,  1.38it/s]
# mkl-service-2.4.0    | 54 KB     | : 100% 1.0/1 [00:00<00:00,  3.50it/s]
# threadpoolctl-2.2.0  | 16 KB     | : 100% 1.0/1 [00:00<00:00,  3.47it/s]
# executing-1.2.0      | 24 KB     | : 100% 1.0/1 [00:00<00:00, 23.04it/s]
# stack_data-0.6.2     | 26 KB     | : 100% 1.0/1 [00:00<00:00,  3.20it/s]
# libxml2-2.10.4       | 755 KB    | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
# wcwidth-0.2.8        | 30 KB     | : 100% 1.0/1 [00:00<00:00,  2.80it/s]
# matplotlib-3.7.2     | 8 KB      | : 100% 1.0/1 [00:00<00:00,  3.45it/s]
# brotli-1.0.9         | 18 KB     | : 100% 1.0/1 [00:00<00:00,  3.35it/s]
# parso-0.8.3          | 69 KB     | : 100% 1.0/1 [00:00<00:00, 17.20it/s]
# ipython-8.16.1       | 577 KB    | : 100% 1.0/1 [00:00<00:00,  2.43it/s]
# aws-c-common-0.6.8   | 177 KB    | : 100% 1.0/1 [00:00<00:00,  3.30it/s]
# exceptiongroup-1.1.3 | 19 KB     | : 100% 1.0/1 [00:00<00:00,  3.31it/s]
# pyzmq-25.1.0         | 538 KB    | : 100% 1.0/1 [00:00<00:00,  2.33it/s]
# pyyaml-6.0.1         | 210 KB    | : 100% 1.0/1 [00:00<00:00,  2.46it/s]
# minio-7.1.0          | 56 KB     | : 100% 1.0/1 [00:00<00:00,  1.51it/s]
# mkl_random-1.2.4     | 316 KB    | : 100% 1.0/1 [00:00<00:00,  2.45it/s]
# fontconfig-2.14.1    | 281 KB    | : 100% 1.0/1 [00:00<00:00,  2.33it/s]
# scikit-optimize-0.9. | 74 KB     | : 100% 1.0/1 [00:00<00:00, 13.71it/s]
# contourpy-1.0.5      | 212 KB    | : 100% 1.0/1 [00:00<00:00,  2.40it/s]
# seaborn-0.12.2       | 570 KB    | : 100% 1.0/1 [00:00<00:00,  2.30it/s]
# pyqt-5.15.7          | 5.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.24it/s]
# pygments-2.16.1      | 833 KB    | : 100% 1.0/1 [00:00<00:00,  2.01it/s]
# libpq-12.15          | 2.4 MB    | : 100% 1.0/1 [00:00<00:00,  1.46it/s]
# glog-0.5.0           | 101 KB    | : 100% 1.0/1 [00:00<00:00,  2.15it/s]
# xmltodict-0.13.0     | 22 KB     | : 100% 1.0/1 [00:00<00:00,  1.50it/s]
# lerc-3.0             | 196 KB    | : 100% 1.0/1 [00:00<00:00,  2.45it/s]
# lz4-c-1.9.4          | 154 KB    | : 100% 1.0/1 [00:00<00:00,  2.39it/s]
# grpc-cpp-1.48.2      | 4.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.47it/s]
# libbrotlicommon-1.0. | 70 KB     | : 100% 1.0/1 [00:00<00:00,  2.50it/s]
# zstd-1.5.5           | 647 KB    | : 100% 1.0/1 [00:00<00:00,  2.26it/s]
# libpng-1.6.39        | 304 KB    | : 100% 1.0/1 [00:00<00:00,  2.39it/s]
# orc-1.7.4            | 972 KB    | : 100% 1.0/1 [00:00<00:00,  2.05it/s]
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00,  2.35it/s]
# pytz-2023.3.post1    | 216 KB    | : 100% 1.0/1 [00:00<00:00,  1.92it/s]
# importlib-metadata-6 | 25 KB     | : 100% 1.0/1 [00:00<00:00,  2.39it/s]
# pyarrow-11.0.0       | 4.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.46it/s]
# tk-8.6.12            | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.73it/s]
# ld_impl_linux-64-2.3 | 654 KB    | : 100% 1.0/1 [00:00<00:00,  2.92it/s]
# cycler-0.11.0        | 12 KB     | : 100% 1.0/1 [00:00<00:00,  3.47it/s]
# _libgcc_mutex-0.1    | 2 KB      | : 100% 1.0/1 [00:00<00:00,  4.76it/s]
# brotlipy-0.7.0       | 307 KB    | : 100% 1.0/1 [00:00<00:00,  3.34it/s]
# toml-0.10.2          | 20 KB     | : 100% 1.0/1 [00:00<00:00,  3.39it/s]
# decorator-5.1.1      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 29.62it/s]
# libcups-2.4.2        | 4.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.70it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  1.95it/s]
# libdeflate-1.17      | 64 KB     | : 100% 1.0/1 [00:00<00:00,  3.41it/s]
# libwebp-1.3.2        | 87 KB     | : 100% 1.0/1 [00:00<00:00,  3.22it/s]
# idna-3.4             | 96 KB     | : 100% 1.0/1 [00:00<00:00,  3.40it/s]
# scikit-learn-1.2.2   | 8.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
# aws-sdk-cpp-1.8.185  | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.27it/s]
# future-0.18.3        | 824 KB    | : 100% 1.0/1 [00:01<00:00,  1.18s/it]
# libevent-2.1.12      | 453 KB    | : 100% 1.0/1 [00:00<00:00,  2.61it/s]
# python-tzdata-2023.3 | 140 KB    | : 100% 1.0/1 [00:00<00:00,  2.85it/s]
# c-ares-1.19.1        | 118 KB    | : 100% 1.0/1 [00:00<00:00,  3.35it/s]
# giflib-5.2.1         | 80 KB     | : 100% 1.0/1 [00:00<00:00,  3.34it/s]
# done
# done
# -
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate automl_2023z_2
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done
